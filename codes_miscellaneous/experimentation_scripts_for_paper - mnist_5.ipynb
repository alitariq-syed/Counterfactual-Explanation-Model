# %%
#%run -i my_interpretable_CNN.py --help

# %%
# for index in range(2):
#     %run -i my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f
#     %load_ext autoreload
#     %autoreload 1

# %%
# for index in range(2):
#     %run -n my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f

# %%
#retrain with threshold = 0.5
# %run -i my_interpretable_CNN.py --train_counterfactual_net=True --alter_class=5 --cfe_epochs=100 --l1_weight=2
# Out:
# TF version:  2.3.0
# ...GPU set_memory_growth successfully set...
# not saving log file
# save_path:  ./trained_weights/myCNN/mnist/standard
# resuming training
#
#  Namespace(alter_class=5, analyze_filter_importance=False, cfe_epochs=100, create_counterfactual_combined=True, dataset='mnist', filter_category_method='own_reduce_loss', filter_modified_directly=True, find_filter_class=False, fine_tune=False, fixed_classes=True, fixed_classes_reduce_loss=True, full_standard=True, high_capacity_model=True, imagenet_weights=False, interpretable=False, l1_weight=2.0, load_counterfactual_net=True, loss_compute=True, model='myCNN/', resume=True, resume_counterfactual_net=False, save_directory='./trained_weights/', save_filter_fmap=False, save_filter_importance=False, save_logFile=False, save_path='./trained_weights/myCNN/mnist/standard', save_top_layer=True, test=True, test_counterfactual_net=False, test_filter_importance=False, train=False, train_counterfactual_net='True', train_using_builtin_fit_method=True, visualize_fmaps=False)
#
# batch_size:  32
# not using imagenet_weights
# Model: "VGG_base_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 12, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# target_conv (Conv2D)            (None, 10, 10, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 5, 5, 128)    0           target_conv[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 128)]        0           global_average_pooling2d[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           1290        tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 10)           0           dense[0][0]
# ==================================================================================================
# Total params: 93,962
# Trainable params: 93,962
# Non-trainable params: 0
# __________________________________________________________________________________________________
# weights loaded
# Testing...
# 100%|████████████████████████████████████████████████████████| 313/313 [00:02<00:00, 114.72it/s, acc=0.983, loss=0.051]
#
# Test loss: 0.050998703
# Test accuracy: 0.9828
# threshold:  0.5
# l1 weight:  2.0
# training CF model for alter class:  5
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# counterfactual_model (Functiona (None, 128)          109184      input_3[0][0]
# __________________________________________________________________________________________________
# VGG_base_model (Functional)     [(None, 10), (None,  93962       input_3[0][0]
#                                                                  counterfactual_model[0][0]
# ==================================================================================================
# Total params: 110,474
# Trainable params: 16,512
# Non-trainable params: 93,962
# __________________________________________________________________________________________________
# training for fixed alter class:  5
# epoch 0: 100%|█| 1875/1875 [00:13<00:00, 143.82it/s, acc=0.997, loss=[0.0323094, 0.7267693, -0.36655742, 0.0, 11.89735]
# epoch 1: 100%|█| 1875/1875 [00:11<00:00, 156.30it/s, acc=1, loss=[0.020826258, 0.40557736, -0.27057585, 0.0, 6.6050167]
# epoch 2: 100%|███| 1875/1875 [00:11<00:00, 158.17it/s, acc=1, loss=[0.023210885, 0.34747863, -0.26282173, 0.0, 5.6379]]
# epoch 3: 100%|██████| 1875/1875 [00:11<00:00, 158.87it/s, acc=1, loss=[0.0226213, 0.34730387, -0.2629106, 0.0, 5.6222]]
# epoch 4: 100%|███| 1875/1875 [00:11<00:00, 157.83it/s, acc=1, loss=[0.022275433, 0.34741083, -0.2632057, 0.0, 5.61555]]
# epoch 5: 100%|█| 1875/1875 [00:11<00:00, 156.92it/s, acc=1, loss=[0.022076042, 0.34749508, -0.26344353, 0.0, 5.6113667]
# epoch 6: 100%|█| 1875/1875 [00:11<00:00, 156.39it/s, acc=1, loss=[0.021963475, 0.34757432, -0.26369256, 0.0, 5.6076665]
# epoch 7: 100%|████| 1875/1875 [00:11<00:00, 157.22it/s, acc=1, loss=[0.021991292, 0.34778818, -0.2641246, 0.0, 5.6079]]
# epoch 8: 100%|█| 1875/1875 [00:11<00:00, 158.85it/s, acc=1, loss=[0.021933118, 0.34787866, -0.26430845, 0.0, 5.606233]]
# epoch 9: 100%|███| 1875/1875 [00:11<00:00, 159.20it/s, acc=1, loss=[0.021995135, 0.34802362, -0.26464394, 0.0, 5.6067]]
# epoch 10: 100%|████| 1875/1875 [00:12<00:00, 154.23it/s, acc=1, loss=[0.02201876, 0.3480502, -0.26477644, 0.0, 5.6045]]
# epoch 11: 100%|██| 1875/1875 [00:12<00:00, 149.26it/s, acc=1, loss=[0.022048887, 0.34810597, -0.2649603, 0.0, 5.60355]]
# epoch 12: 100%|██| 1875/1875 [00:11<00:00, 158.51it/s, acc=1, loss=[0.0220499, 0.3481879, -0.26512158, 0.0, 5.6033835]]
# epoch 13: 100%|█| 1875/1875 [00:11<00:00, 166.59it/s, acc=1, loss=[0.022084866, 0.3482864, -0.26534382, 0.0, 5.6045165]
# epoch 14: 100%|██| 1875/1875 [00:11<00:00, 166.99it/s, acc=1, loss=[0.024333548, 0.3333865, -0.259657, 0.0, 5.4262333]]
# epoch 15: 100%|█| 1875/1875 [00:11<00:00, 165.10it/s, acc=1, loss=[0.027026244, 0.31325147, -0.25242642, 0.0, 5.1608667
# epoch 16: 100%|██| 1875/1875 [00:11<00:00, 165.70it/s, acc=1, loss=[0.026788415, 0.31301707, -0.25259873, 0.0, 5.1473]]
# epoch 17: 100%|█| 1875/1875 [00:11<00:00, 166.53it/s, acc=1, loss=[0.026724264, 0.31278485, -0.25266725, 0.0, 5.137367]
# epoch 18: 100%|█| 1875/1875 [00:11<00:00, 166.21it/s, acc=1, loss=[0.02666646, 0.31275874, -0.25285864, 0.0, 5.1323667]
# epoch 19: 100%|██| 1875/1875 [00:11<00:00, 163.54it/s, acc=1, loss=[0.02655674, 0.31272697, -0.2529177, 0.0, 5.129083]]
# epoch 20: 100%|█| 1875/1875 [00:11<00:00, 157.39it/s, acc=1, loss=[0.026592487, 0.31264603, -0.25302908, 0.0, 5.125167]
# epoch 21: 100%|███| 1875/1875 [00:11<00:00, 161.87it/s, acc=1, loss=[0.026411287, 0.3128356, -0.25325722, 0.0, 5.1266]]
# epoch 22: 100%|██| 1875/1875 [00:11<00:00, 163.21it/s, acc=1, loss=[0.026397493, 0.3128827, -0.2534157, 0.0, 5.125183]]
# epoch 23: 100%|█| 1875/1875 [00:11<00:00, 164.17it/s, acc=1, loss=[0.026321013, 0.31275958, -0.2533069, 0.0, 5.121383]]
# epoch 24: 100%|███| 1875/1875 [00:12<00:00, 156.03it/s, acc=1, loss=[0.026275923, 0.3128997, -0.2535342, 0.0, 5.12255]]
# epoch 25: 100%|██| 1875/1875 [00:11<00:00, 157.44it/s, acc=1, loss=[0.0262393, 0.31294248, -0.2536237, 0.0, 5.1218166]]
# epoch 26: 100%|██| 1875/1875 [00:13<00:00, 143.56it/s, acc=1, loss=[0.026215421, 0.31295702, -0.25369868, 0.0, 5.1207]]
# epoch 27: 100%|██| 1875/1875 [00:11<00:00, 160.00it/s, acc=1, loss=[0.026185304, 0.31308, -0.25386924, 0.0, 5.1222167]]
# epoch 28: 100%|█| 1875/1875 [00:11<00:00, 166.03it/s, acc=1, loss=[0.026121445, 0.31302568, -0.25383478, 0.0, 5.120633]
# epoch 29: 100%|█| 1875/1875 [00:11<00:00, 166.79it/s, acc=1, loss=[0.026119495, 0.31304196, -0.25391087, 0.0, 5.1192665
# epoch 30: 100%|██| 1875/1875 [00:11<00:00, 167.20it/s, acc=1, loss=[0.026042743, 0.31314456, -0.25401047, 0.0, 5.1208]]
# epoch 31: 100%|█| 1875/1875 [00:11<00:00, 161.48it/s, acc=1, loss=[0.026025634, 0.31318435, -0.254091, 0.0, 5.1211834]]
# epoch 32: 100%|█| 1875/1875 [00:11<00:00, 162.56it/s, acc=1, loss=[0.025965873, 0.3131556, -0.25408065, 0.0, 5.1210833]
# epoch 33: 100%|██████| 1875/1875 [00:11<00:00, 167.00it/s, acc=1, loss=[0.025794491, 0.31326, -0.2541238, 0.0, 5.1238]]
# epoch 34: 100%|█| 1875/1875 [00:11<00:00, 166.55it/s, acc=1, loss=[0.025575813, 0.31320843, -0.25404426, 0.0, 5.12535]]
# epoch 35: 100%|█| 1875/1875 [00:11<00:00, 167.55it/s, acc=1, loss=[0.02529989, 0.31311774, -0.25389594, 0.0, 5.125517]]
# epoch 36: 100%|█| 1875/1875 [00:11<00:00, 159.61it/s, acc=1, loss=[0.025192913, 0.31306663, -0.25389963, 0.0, 5.1247334
# epoch 37: 100%|█| 1875/1875 [00:11<00:00, 160.48it/s, acc=1, loss=[0.025092676, 0.31301796, -0.25390312, 0.0, 5.124017]
# epoch 38: 100%|█| 1875/1875 [00:11<00:00, 168.27it/s, acc=1, loss=[0.025045402, 0.31306413, -0.254016, 0.0, 5.1244335]]
# epoch 39: 100%|█| 1875/1875 [00:11<00:00, 165.11it/s, acc=1, loss=[0.025009869, 0.31296065, -0.25394765, 0.0, 5.12185]]
# epoch 40: 100%|█| 1875/1875 [00:11<00:00, 165.48it/s, acc=1, loss=[0.024969386, 0.31304616, -0.25412196, 0.0, 5.123317]
# epoch 41: 100%|██| 1875/1875 [03:31<00:00,  8.87it/s, acc=1, loss=[0.024979176, 0.31312355, -0.25426212, 0.0, 5.12415]]
# epoch 42: 100%|█| 1875/1875 [00:11<00:00, 163.11it/s, acc=1, loss=[0.024905857, 0.31306574, -0.25419956, 0.0, 5.122733]
# epoch 43: 100%|██| 1875/1875 [00:11<00:00, 163.60it/s, acc=1, loss=[0.024894075, 0.31323728, -0.2544409, 0.0, 5.12615]]
# epoch 44: 100%|█| 1875/1875 [00:11<00:00, 165.97it/s, acc=1, loss=[0.024844041, 0.3133216, -0.25455025, 0.0, 5.1278834]
# epoch 45: 100%|███| 1875/1875 [00:11<00:00, 165.22it/s, acc=1, loss=[0.02483773, 0.31321433, -0.2544911, 0.0, 5.12555]]
# epoch 46: 100%|██| 1875/1875 [00:11<00:00, 165.60it/s, acc=1, loss=[0.02476015, 0.31340784, -0.25466856, 0.0, 5.12915]]
# epoch 47: 100%|██| 1875/1875 [00:11<00:00, 165.37it/s, acc=1, loss=[0.02476788, 0.31339547, -0.25473055, 0.0, 5.12885]]
# epoch 48: 100%|██| 1875/1875 [00:11<00:00, 166.23it/s, acc=1, loss=[0.024738792, 0.31352723, -0.25485054, 0.0, 5.1315]]
# epoch 49: 100%|██| 1875/1875 [00:11<00:00, 166.75it/s, acc=1, loss=[0.024704471, 0.31351703, -0.25486982, 0.0, 5.1313]]
# epoch 50: 100%|█| 1875/1875 [00:11<00:00, 166.04it/s, acc=1, loss=[0.024658138, 0.3135451, -0.25487852, 0.0, 5.1316833]
# epoch 51: 100%|█| 1875/1875 [00:11<00:00, 166.28it/s, acc=1, loss=[0.024666168, 0.31360593, -0.25499195, 0.0, 5.1329665
# epoch 52: 100%|█| 1875/1875 [00:11<00:00, 166.09it/s, acc=1, loss=[0.024646807, 0.3137161, -0.2551321, 0.0, 5.1348667]]
# epoch 53: 100%|████| 1875/1875 [00:11<00:00, 162.69it/s, acc=1, loss=[0.02456794, 0.31377122, -0.2551547, 0.0, 5.1359]]
# epoch 54: 100%|█| 1875/1875 [00:11<00:00, 161.44it/s, acc=1, loss=[0.024560226, 0.31378534, -0.25520107, 0.0, 5.13555]]
# epoch 55: 100%|██| 1875/1875 [00:11<00:00, 162.30it/s, acc=1, loss=[0.024533948, 0.31377268, -0.25519016, 0.0, 5.1351]]
# epoch 56: 100%|█| 1875/1875 [00:11<00:00, 164.07it/s, acc=1, loss=[0.024506116, 0.31390548, -0.25534526, 0.0, 5.1379333
# epoch 57: 100%|█| 1875/1875 [00:11<00:00, 166.80it/s, acc=1, loss=[0.024490057, 0.31402412, -0.25550023, 0.0, 5.13995]]
# epoch 58: 100%|█| 1875/1875 [00:11<00:00, 165.88it/s, acc=1, loss=[0.02448811, 0.31391802, -0.25541404, 0.0, 5.1375666]
# epoch 59: 100%|█████| 1875/1875 [00:11<00:00, 167.62it/s, acc=1, loss=[0.02443202, 0.31405962, -0.255527, 0.0, 5.1406]]
# epoch 60: 100%|████| 1875/1875 [00:11<00:00, 168.01it/s, acc=1, loss=[0.02446795, 0.31403002, -0.2555753, 0.0, 5.1395]]
# epoch 61: 100%|█| 1875/1875 [00:11<00:00, 167.28it/s, acc=1, loss=[0.024425907, 0.3139653, -0.25548056, 0.0, 5.1376166]
# epoch 62: 100%|█| 1875/1875 [00:11<00:00, 167.18it/s, acc=1, loss=[0.024407886, 0.31418994, -0.2557409, 0.0, 5.1421666]
# epoch 63: 100%|█| 1875/1875 [00:11<00:00, 166.79it/s, acc=1, loss=[0.024363238, 0.31418395, -0.25571164, 0.0, 5.14205]]
# epoch 64: 100%|██| 1875/1875 [00:11<00:00, 166.54it/s, acc=1, loss=[0.024403684, 0.3141105, -0.2557049, 0.0, 5.140217]]
# epoch 65: 100%|█| 1875/1875 [00:11<00:00, 167.26it/s, acc=1, loss=[0.02436947, 0.31434965, -0.2559571, 0.0, 5.1446333]]
# epoch 66: 100%|█| 1875/1875 [00:11<00:00, 167.69it/s, acc=1, loss=[0.024348494, 0.31428385, -0.25589874, 0.0, 5.143417]
# epoch 67: 100%|██| 1875/1875 [00:11<00:00, 167.08it/s, acc=1, loss=[0.02430915, 0.3143135, -0.2559149, 0.0, 5.1434665]]
# epoch 68: 100%|█| 1875/1875 [00:11<00:00, 166.34it/s, acc=1, loss=[0.02430934, 0.31442532, -0.25606832, 0.0, 5.1464834]
# epoch 69: 100%|█| 1875/1875 [00:11<00:00, 167.75it/s, acc=1, loss=[0.024314659, 0.3144041, -0.25606138, 0.0, 5.1450334]
# epoch 70: 100%|█| 1875/1875 [00:11<00:00, 168.06it/s, acc=1, loss=[0.024299389, 0.31438163, -0.2560648, 0.0, 5.1450667]
# epoch 71: 100%|██| 1875/1875 [00:11<00:00, 167.31it/s, acc=1, loss=[0.02424877, 0.3144948, -0.25615567, 0.0, 5.147033]]
# epoch 72: 100%|███| 1875/1875 [00:11<00:00, 166.58it/s, acc=1, loss=[0.024258483, 0.31444857, -0.2561443, 0.0, 5.1464]]
# epoch 73: 100%|█| 1875/1875 [00:11<00:00, 167.66it/s, acc=1, loss=[0.024237866, 0.31454095, -0.25622952, 0.0, 5.147033]
# epoch 74: 100%|██| 1875/1875 [00:11<00:00, 167.33it/s, acc=1, loss=[0.02425676, 0.3145514, -0.2562968, 0.0, 5.1475835]]
# epoch 75: 100%|███| 1875/1875 [00:11<00:00, 169.20it/s, acc=1, loss=[0.024242947, 0.3146085, -0.25636125, 0.0, 5.1488]]
# epoch 76: 100%|█| 1875/1875 [00:11<00:00, 167.20it/s, acc=1, loss=[0.02424308, 0.31457162, -0.25634196, 0.0, 5.147733]]
# epoch 77: 100%|█| 1875/1875 [00:11<00:00, 167.31it/s, acc=1, loss=[0.024165243, 0.31467673, -0.2564045, 0.0, 5.1497664]
# epoch 78: 100%|██| 1875/1875 [00:11<00:00, 167.75it/s, acc=1, loss=[0.024230855, 0.31452918, -0.256334, 0.0, 5.146683]]
# epoch 79: 100%|█| 1875/1875 [00:11<00:00, 168.19it/s, acc=1, loss=[0.024153404, 0.31476247, -0.25652856, 0.0, 5.15145]]
# epoch 80: 100%|█| 1875/1875 [00:11<00:00, 168.36it/s, acc=1, loss=[0.024156583, 0.3147892, -0.25658134, 0.0, 5.151767]]
# epoch 81: 100%|██| 1875/1875 [00:11<00:00, 168.01it/s, acc=1, loss=[0.024191955, 0.31465462, -0.25649393, 0.0, 5.1488]]
# epoch 82: 100%|█| 1875/1875 [00:11<00:00, 169.49it/s, acc=1, loss=[0.02415037, 0.31468415, -0.25649646, 0.0, 5.1493835]
# epoch 83: 100%|███| 1875/1875 [00:11<00:00, 166.67it/s, acc=1, loss=[0.02414529, 0.31474292, -0.25660047, 0.0, 5.1508]]
# epoch 84: 100%|████| 1875/1875 [00:11<00:00, 167.37it/s, acc=1, loss=[0.02416346, 0.31471065, -0.2565786, 0.0, 5.1497]]
# epoch 85: 100%|██| 1875/1875 [00:11<00:00, 167.66it/s, acc=1, loss=[0.024138635, 0.31470716, -0.2565943, 0.0, 5.15025]]
# epoch 86: 100%|██| 1875/1875 [00:11<00:00, 168.00it/s, acc=1, loss=[0.02414745, 0.3146986, -0.2566164, 0.0, 5.1504664]]
# epoch 87: 100%|█| 1875/1875 [00:11<00:00, 168.00it/s, acc=1, loss=[0.024138404, 0.31469473, -0.25663632, 0.0, 5.15135]]
# epoch 88: 100%|█| 1875/1875 [00:11<00:00, 167.71it/s, acc=1, loss=[0.024206506, 0.31454498, -0.25658026, 0.0, 5.151067]
# epoch 89: 100%|█| 1875/1875 [00:11<00:00, 167.86it/s, acc=1, loss=[0.024319028, 0.3143264, -0.25655746, 0.0, 5.154217]]
# epoch 90: 100%|█| 1875/1875 [00:11<00:00, 167.72it/s, acc=1, loss=[0.024882825, 0.3130974, -0.2559937, 0.0, 5.1519666]]
# epoch 91: 100%|███| 1875/1875 [00:11<00:00, 167.79it/s, acc=1, loss=[0.025607023, 0.3119365, -0.25569612, 0.0, 5.1361]]
# epoch 92: 100%|█| 1875/1875 [00:11<00:00, 167.92it/s, acc=1, loss=[0.025730975, 0.3116564, -0.25561902, 0.0, 5.1269665]
# epoch 93: 100%|██| 1875/1875 [00:11<00:00, 167.60it/s, acc=1, loss=[0.025741275, 0.3114952, -0.2555519, 0.0, 5.122383]]
# epoch 94: 100%|█| 1875/1875 [00:11<00:00, 166.09it/s, acc=1, loss=[0.025760494, 0.31146654, -0.25559807, 0.0, 5.1197667
# epoch 95: 100%|██| 1875/1875 [00:11<00:00, 167.27it/s, acc=1, loss=[0.025832908, 0.31121284, -0.2554635, 0.0, 5.11575]]
# epoch 96: 100%|█| 1875/1875 [00:11<00:00, 168.11it/s, acc=1, loss=[0.025821872, 0.31124118, -0.25550625, 0.0, 5.1162167
# epoch 97: 100%|█| 1875/1875 [00:11<00:00, 168.03it/s, acc=1, loss=[0.025829552, 0.31109333, -0.2554236, 0.0, 5.1142836]
# epoch 98: 100%|█| 1875/1875 [00:11<00:00, 167.46it/s, acc=1, loss=[0.025898453, 0.31096128, -0.25539377, 0.0, 5.1137834
# epoch 99: 100%|█| 1875/1875 [00:11<00:00, 166.78it/s, acc=1, loss=[0.025957283, 0.31069437, -0.25522363, 0.0, 5.11125]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# E:\Medical Imaging Diagnostic (MID) Lab\XAI in MID\my_implementation_interpretable_CNN\my_interpretable_CNN.py in <module>
#    1107         ipython = get_ipython()
#    1108         ipython.magic("reset -f")
# -> 1109         sys.exit()
#    1110     else:
#    1111         #counterfactual_generator.load_weights(filepath=weights_path+'/counterfactual_generator_model.hdf5')
#
# NameError: name 'sys' is not defined
