# %%
#%run -i my_interpretable_CNN.py --help

# %%
# for index in range(2):
#     %run -i my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f
#     %load_ext autoreload
#     %autoreload 1

# %%
# for index in range(2):
#     %run -n my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f

# %%
#retrain with threshold = 0.5
# %run -i my_interpretable_CNN.py --train_counterfactual_net=True --alter_class=8 --cfe_epochs=100 --l1_weight=2
# Out:
# TF version:  2.3.0
# ...GPU set_memory_growth successfully set...
# not saving log file
# save_path:  ./trained_weights/myCNN/mnist/standard
# resuming training
#
#  Namespace(alter_class=8, alter_class_2=5, analysis_class=5, analyze_filter_importance=False, cfe_epochs=100, counterfactual_PP=True, create_counterfactual_combined=True, dataset='mnist', filter_category_method='own_reduce_loss', filter_modified_directly=True, find_filter_class=False, find_global_filters=False, fine_tune=False, fixed_classes=True, fixed_classes_reduce_loss=True, full_standard=True, high_capacity_model=True, imagenet_weights=False, interpretable=False, l1_weight=2.0, load_counterfactual_net=True, loss_compute=True, model='myCNN/', resume=True, resume_counterfactual_net=False, save_directory='./trained_weights/', save_filter_fmap=False, save_filter_importance=False, save_logFile=False, save_path='./trained_weights/myCNN/mnist/standard', save_top_layer=True, test=False, test_counterfactual_net=False, test_filter_importance=False, train=False, train_counterfactual_net='True', train_using_builtin_fit_method=True, visualize_fmaps=False)
#
# batch_size:  32
# not using imagenet_weights
# Model: "VGG_base_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 12, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# target_conv (Conv2D)            (None, 10, 10, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 5, 5, 128)    0           target_conv[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 128)]        0           global_average_pooling2d[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           1290        tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 10)           0           dense[0][0]
# ==================================================================================================
# Total params: 93,962
# Trainable params: 93,962
# Non-trainable params: 0
# __________________________________________________________________________________________________
# weights loaded
# threshold:  0.5
# l1 weight:  2.0
# training CF model for alter class:  8
# Training CF model for PPs
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# counterfactual_model (Functiona (None, 128)          109184      input_3[0][0]
# __________________________________________________________________________________________________
# VGG_base_model (Functional)     [(None, 10), (None,  93962       input_3[0][0]
#                                                                  counterfactual_model[0][0]
# ==================================================================================================
# Total params: 110,474
# Trainable params: 16,512
# Non-trainable params: 93,962
# __________________________________________________________________________________________________
# training for fixed alter class:  8
# epoch 0: 100%|█| 1875/1875 [00:14<00:00, 133.42it/s, acc=0.998, loss=[0.01431667, 0.73905975, -0.41031936, 0.0, 12.5358
# epoch 1: 100%|██| 1875/1875 [00:11<00:00, 160.89it/s, acc=1, loss=[0.00880299, 0.3846647, -0.38120902, 0.0, 6.5381665]]
# epoch 2: 100%|████| 1875/1875 [00:11<00:00, 158.98it/s, acc=1, loss=[0.008752496, 0.3820595, -0.38111597, 0.0, 6.4464]]
# epoch 3: 100%|█| 1875/1875 [00:12<00:00, 155.45it/s, acc=1, loss=[0.009900602, 0.31974167, -0.34298575, 0.0, 5.507167]]
# epoch 4: 100%|█| 1875/1875 [00:11<00:00, 159.31it/s, acc=1, loss=[0.010783571, 0.30879956, -0.3361934, 0.0, 5.3166165]]
# epoch 5: 100%|██| 1875/1875 [00:11<00:00, 156.80it/s, acc=1, loss=[0.010956208, 0.30561674, -0.33393115, 0.0, 5.24555]]
# epoch 6: 100%|█| 1875/1875 [00:12<00:00, 155.32it/s, acc=1, loss=[0.01107568, 0.30396006, -0.33293998, 0.0, 5.2030334]]
# epoch 7: 100%|██████| 1875/1875 [00:11<00:00, 157.85it/s, acc=1, loss=[0.011133182, 0.3029679, -0.332453, 0.0, 5.1719]]
# epoch 8: 100%|███| 1875/1875 [00:12<00:00, 155.80it/s, acc=1, loss=[0.01121432, 0.30202332, -0.33194345, 0.0, 5.14685]]
# epoch 9: 100%|█| 1875/1875 [00:12<00:00, 156.24it/s, acc=1, loss=[0.011255029, 0.30136693, -0.3316323, 0.0, 5.1282167]]
# epoch 10: 100%|█| 1875/1875 [00:11<00:00, 158.88it/s, acc=1, loss=[0.011255041, 0.30105358, -0.33159187, 0.0, 5.116083]
# epoch 11: 100%|█| 1875/1875 [00:11<00:00, 156.79it/s, acc=1, loss=[0.011296583, 0.3003924, -0.33120987, 0.0, 5.1008334]
# epoch 12: 100%|█| 1875/1875 [00:11<00:00, 157.17it/s, acc=1, loss=[0.011317118, 0.2999694, -0.33101714, 0.0, 5.0917335]
# epoch 13: 100%|█| 1875/1875 [00:11<00:00, 160.68it/s, acc=1, loss=[0.011364468, 0.2995218, -0.3308003, 0.0, 5.0822334]]
# epoch 14: 100%|█| 1875/1875 [00:12<00:00, 154.36it/s, acc=1, loss=[0.011394711, 0.2990521, -0.33052865, 0.0, 5.073933]]
# epoch 15: 100%|█| 1875/1875 [00:12<00:00, 155.71it/s, acc=1, loss=[0.011412298, 0.29880512, -0.33047047, 0.0, 5.0670834
# epoch 16: 100%|██| 1875/1875 [00:11<00:00, 157.35it/s, acc=1, loss=[0.011452577, 0.29841605, -0.33026853, 0.0, 5.0599]]
# epoch 17: 100%|█| 1875/1875 [00:11<00:00, 157.50it/s, acc=1, loss=[0.011472927, 0.29807028, -0.33009222, 0.0, 5.052817]
# epoch 18: 100%|█| 1875/1875 [00:11<00:00, 158.57it/s, acc=1, loss=[0.011474886, 0.29774135, -0.32990924, 0.0, 5.0463667
# epoch 19: 100%|█| 1875/1875 [00:11<00:00, 157.12it/s, acc=1, loss=[0.011480072, 0.29752874, -0.32984844, 0.0, 5.041983]
# epoch 20: 100%|████| 1875/1875 [00:11<00:00, 157.28it/s, acc=1, loss=[0.011476546, 0.2972059, -0.3296542, 0.0, 5.0355]]
# epoch 21: 100%|█| 1875/1875 [00:11<00:00, 160.62it/s, acc=1, loss=[0.011458145, 0.29709288, -0.32965332, 0.0, 5.0305333
# epoch 22: 100%|█| 1875/1875 [00:11<00:00, 160.28it/s, acc=1, loss=[0.011465932, 0.2969074, -0.3295853, 0.0, 5.0261335]]
# epoch 23: 100%|█| 1875/1875 [00:12<00:00, 154.71it/s, acc=1, loss=[0.011473393, 0.29664078, -0.32943416, 0.0, 5.01915]]
# epoch 24: 100%|█| 1875/1875 [00:12<00:00, 153.14it/s, acc=1, loss=[0.011443086, 0.2966323, -0.32950157, 0.0, 5.0169168]
# epoch 25: 100%|█| 1875/1875 [00:13<00:00, 138.13it/s, acc=1, loss=[0.011437672, 0.29642355, -0.32938272, 0.0, 5.01215]]
# epoch 26: 100%|█| 1875/1875 [00:11<00:00, 161.44it/s, acc=1, loss=[0.0114275, 0.29634035, -0.32938412, 0.0, 5.0078335]]
# epoch 27: 100%|██| 1875/1875 [00:12<00:00, 155.66it/s, acc=1, loss=[0.011430026, 0.29612786, -0.32925963, 0.0, 5.0021]]
# epoch 28: 100%|█| 1875/1875 [00:12<00:00, 155.85it/s, acc=1, loss=[0.011406234, 0.29615188, -0.3293383, 0.0, 5.0004835]
# epoch 29: 100%|█| 1875/1875 [00:11<00:00, 162.00it/s, acc=1, loss=[0.011409003, 0.29592255, -0.32919258, 0.0, 4.995283]
# epoch 30: 100%|█| 1875/1875 [00:11<00:00, 160.63it/s, acc=1, loss=[0.0113877095, 0.2958961, -0.32921642, 0.0, 4.9923167
# epoch 31: 100%|█| 1875/1875 [00:12<00:00, 153.27it/s, acc=1, loss=[0.011362319, 0.29582122, -0.32919952, 0.0, 4.9884167
# epoch 32: 100%|█| 1875/1875 [00:12<00:00, 154.54it/s, acc=1, loss=[0.011381425, 0.2957237, -0.3291746, 0.0, 4.9854665]]
# epoch 33: 100%|██| 1875/1875 [00:11<00:00, 156.54it/s, acc=1, loss=[0.011341917, 0.29574686, -0.32923374, 0.0, 4.9834]]
# epoch 34: 100%|████| 1875/1875 [00:11<00:00, 161.96it/s, acc=1, loss=[0.01134285, 0.29563978, -0.3291841, 0.0, 4.9796]]
# epoch 35: 100%|███| 1875/1875 [00:11<00:00, 161.55it/s, acc=1, loss=[0.011326571, 0.29552796, -0.329113, 0.0, 4.97685]]
# epoch 36: 100%|█| 1875/1875 [00:11<00:00, 163.90it/s, acc=1, loss=[0.011329305, 0.295376, -0.32901502, 0.0, 4.9732165]]
# epoch 37: 100%|█| 1875/1875 [00:11<00:00, 163.34it/s, acc=1, loss=[0.011305246, 0.29552045, -0.32918787, 0.0, 4.9731665
# epoch 38: 100%|█| 1875/1875 [00:11<00:00, 157.28it/s, acc=1, loss=[0.011298053, 0.29538757, -0.32910505, 0.0, 4.97015]]
# epoch 39: 100%|█| 1875/1875 [00:11<00:00, 159.90it/s, acc=1, loss=[0.011288269, 0.29531285, -0.32907137, 0.0, 4.96725]]
# epoch 40: 100%|██| 1875/1875 [00:12<00:00, 155.94it/s, acc=1, loss=[0.011266732, 0.2952935, -0.3290766, 0.0, 4.965833]]
# epoch 41: 100%|█| 1875/1875 [00:11<00:00, 160.52it/s, acc=1, loss=[0.011257791, 0.2952166, -0.32903743, 0.0, 4.9630833]
# epoch 42: 100%|██| 1875/1875 [00:11<00:00, 161.94it/s, acc=1, loss=[0.011245105, 0.29529792, -0.32914817, 0.0, 4.9636]]
# epoch 43: 100%|█| 1875/1875 [00:12<00:00, 149.90it/s, acc=1, loss=[0.011246168, 0.2951123, -0.32901102, 0.0, 4.9597335]
# epoch 44: 100%|██| 1875/1875 [00:13<00:00, 136.06it/s, acc=1, loss=[0.011218757, 0.2951925, -0.32910857, 0.0, 4.96015]]
# epoch 45: 100%|█| 1875/1875 [00:12<00:00, 151.41it/s, acc=1, loss=[0.011199094, 0.29512534, -0.32907018, 0.0, 4.9590836
# epoch 46: 100%|█| 1875/1875 [00:12<00:00, 148.50it/s, acc=1, loss=[0.011167128, 0.29511413, -0.32907966, 0.0, 4.9583836
# epoch 47: 100%|██| 1875/1875 [00:11<00:00, 157.25it/s, acc=1, loss=[0.011140656, 0.29518634, -0.32916734, 0.0, 4.9598]]
# epoch 48: 100%|█| 1875/1875 [00:12<00:00, 155.41it/s, acc=1, loss=[0.011111595, 0.29517484, -0.3291779, 0.0, 4.959533]]
# epoch 49: 100%|█| 1875/1875 [00:11<00:00, 157.92it/s, acc=1, loss=[0.011084078, 0.29503942, -0.32906744, 0.0, 4.958017]
# epoch 50: 100%|█| 1875/1875 [00:11<00:00, 159.85it/s, acc=1, loss=[0.011023894, 0.29519278, -0.3292123, 0.0, 4.960583]]
# epoch 51: 100%|█| 1875/1875 [00:11<00:00, 157.58it/s, acc=1, loss=[0.010997411, 0.29512784, -0.3291732, 0.0, 4.9604335]
# epoch 52: 100%|██| 1875/1875 [00:11<00:00, 158.70it/s, acc=1, loss=[0.01094534, 0.2952647, -0.32931045, 0.0, 4.964383]]
# epoch 53: 100%|█| 1875/1875 [00:11<00:00, 157.65it/s, acc=1, loss=[0.010883157, 0.2952468, -0.32928762, 0.0, 4.9653835]
# epoch 54: 100%|█| 1875/1875 [00:13<00:00, 143.57it/s, acc=1, loss=[0.01086921, 0.29516464, -0.3292436, 0.0, 4.9645834]]
# epoch 55: 100%|██| 1875/1875 [00:11<00:00, 159.96it/s, acc=1, loss=[0.010839674, 0.29516, -0.32925054, 0.0, 4.9655833]]
# epoch 56: 100%|█| 1875/1875 [00:11<00:00, 160.51it/s, acc=1, loss=[0.0108017875, 0.29520458, -0.32930502, 0.0, 4.966633
# epoch 57: 100%|█| 1875/1875 [00:11<00:00, 159.38it/s, acc=1, loss=[0.010792124, 0.2952028, -0.32933056, 0.0, 4.966767]]
# epoch 58: 100%|███| 1875/1875 [00:11<00:00, 161.04it/s, acc=1, loss=[0.010778916, 0.29509655, -0.3292532, 0.0, 4.9661]]
# epoch 59: 100%|██| 1875/1875 [00:11<00:00, 160.68it/s, acc=1, loss=[0.010765339, 0.2951846, -0.32936135, 0.0, 4.96645]]
# epoch 60: 100%|██| 1875/1875 [00:12<00:00, 155.40it/s, acc=1, loss=[0.01075274, 0.29498652, -0.32918453, 0.0, 4.96475]]
# epoch 61: 100%|█| 1875/1875 [00:11<00:00, 156.45it/s, acc=1, loss=[0.010751358, 0.29504138, -0.3292701, 0.0, 4.9649334]
# epoch 62: 100%|█| 1875/1875 [00:12<00:00, 146.38it/s, acc=1, loss=[0.0107529145, 0.29486072, -0.32911628, 0.0, 4.96255]
# epoch 63: 100%|█| 1875/1875 [00:13<00:00, 141.80it/s, acc=1, loss=[0.010739692, 0.29495898, -0.32923365, 0.0, 4.9631834
# epoch 64: 100%|██| 1875/1875 [00:11<00:00, 158.74it/s, acc=1, loss=[0.010744176, 0.29475063, -0.32906252, 0.0, 4.9597]]
# epoch 65: 100%|█| 1875/1875 [00:11<00:00, 161.09it/s, acc=1, loss=[0.010742107, 0.29476866, -0.32910222, 0.0, 4.9592834
# epoch 66: 100%|█| 1875/1875 [00:11<00:00, 162.41it/s, acc=1, loss=[0.010731285, 0.29473263, -0.32907748, 0.0, 4.9590836
# epoch 67: 100%|█| 1875/1875 [00:11<00:00, 162.40it/s, acc=1, loss=[0.010735437, 0.2946415, -0.32902187, 0.0, 4.9565835]
# epoch 68: 100%|█| 1875/1875 [00:11<00:00, 157.43it/s, acc=1, loss=[0.0107436385, 0.29453993, -0.32894784, 0.0, 4.95465]
# epoch 69: 100%|█| 1875/1875 [00:11<00:00, 158.49it/s, acc=1, loss=[0.010745325, 0.29448697, -0.32892016, 0.0, 4.953117]
# epoch 70: 100%|█| 1875/1875 [00:13<00:00, 140.57it/s, acc=1, loss=[0.0107492665, 0.29448792, -0.32894143, 0.0, 4.95295]
# epoch 71: 100%|█| 1875/1875 [00:11<00:00, 158.19it/s, acc=1, loss=[0.010751536, 0.29438215, -0.32886764, 0.0, 4.9498334
# epoch 72: 100%|██| 1875/1875 [00:11<00:00, 158.35it/s, acc=1, loss=[0.010766656, 0.2943278, -0.32884622, 0.0, 4.94915]]
# epoch 73: 100%|█| 1875/1875 [00:11<00:00, 156.55it/s, acc=1, loss=[0.010759867, 0.29427552, -0.32880682, 0.0, 4.9477167
# epoch 74: 100%|█| 1875/1875 [00:11<00:00, 162.33it/s, acc=1, loss=[0.010766996, 0.29417777, -0.32874072, 0.0, 4.945433]
# epoch 75: 100%|█| 1875/1875 [00:11<00:00, 161.31it/s, acc=1, loss=[0.010760074, 0.29412907, -0.3287034, 0.0, 4.9448166]
# epoch 76: 100%|█| 1875/1875 [00:11<00:00, 160.22it/s, acc=1, loss=[0.010780673, 0.2940212, -0.32864103, 0.0, 4.9420667]
# epoch 77: 100%|█| 1875/1875 [00:11<00:00, 161.48it/s, acc=1, loss=[0.010759758, 0.29410046, -0.32872084, 0.0, 4.9431334
# epoch 78: 100%|███| 1875/1875 [00:11<00:00, 161.16it/s, acc=1, loss=[0.010774831, 0.2939005, -0.32855782, 0.0, 4.9397]]
# epoch 79: 100%|█| 1875/1875 [00:11<00:00, 159.18it/s, acc=1, loss=[0.010763269, 0.29400346, -0.32866052, 0.0, 4.9404335
# epoch 80: 100%|█| 1875/1875 [00:11<00:00, 161.78it/s, acc=1, loss=[0.010771912, 0.2937534, -0.32844678, 0.0, 4.9370666]
# epoch 81: 100%|█| 1875/1875 [00:11<00:00, 157.20it/s, acc=1, loss=[0.010787974, 0.29385868, -0.32858363, 0.0, 4.9377666
# epoch 82: 100%|█| 1875/1875 [00:11<00:00, 159.86it/s, acc=1, loss=[0.01077838, 0.2938321, -0.32856157, 0.0, 4.9375668]]
# epoch 83: 100%|█| 1875/1875 [00:11<00:00, 161.09it/s, acc=1, loss=[0.010795966, 0.29371762, -0.3284834, 0.0, 4.9344335]
# epoch 84: 100%|█| 1875/1875 [00:11<00:00, 161.02it/s, acc=1, loss=[0.010788095, 0.29362908, -0.3284057, 0.0, 4.9339833]
# epoch 85: 100%|█| 1875/1875 [00:11<00:00, 160.94it/s, acc=1, loss=[0.010790621, 0.29362863, -0.32841986, 0.0, 4.93385]]
# epoch 86: 100%|█| 1875/1875 [00:11<00:00, 161.99it/s, acc=1, loss=[0.010808202, 0.2934838, -0.3283119, 0.0, 4.9307165]]
# epoch 87: 100%|█| 1875/1875 [00:11<00:00, 158.98it/s, acc=1, loss=[0.0108125685, 0.29349086, -0.32834166, 0.0, 4.930666
# epoch 88: 100%|█| 1875/1875 [00:12<00:00, 155.20it/s, acc=1, loss=[0.010806263, 0.2934528, -0.32830834, 0.0, 4.9300833]
# epoch 89: 100%|█| 1875/1875 [00:11<00:00, 158.47it/s, acc=1, loss=[0.010823214, 0.29333213, -0.32822827, 0.0, 4.92765]]
# epoch 90: 100%|█| 1875/1875 [00:12<00:00, 155.86it/s, acc=1, loss=[0.0108199725, 0.2933828, -0.32828966, 0.0, 4.9277167
# epoch 91: 100%|█| 1875/1875 [00:11<00:00, 160.57it/s, acc=1, loss=[0.010817011, 0.2932409, -0.32816613, 0.0, 4.9259334]
# epoch 92: 100%|█| 1875/1875 [00:11<00:00, 160.18it/s, acc=1, loss=[0.010831414, 0.2932035, -0.32816178, 0.0, 4.9244165]
# epoch 93: 100%|█| 1875/1875 [00:11<00:00, 160.17it/s, acc=1, loss=[0.010814539, 0.29318398, -0.32814187, 0.0, 4.923917]
# epoch 94: 100%|█| 1875/1875 [00:11<00:00, 159.97it/s, acc=1, loss=[0.010836336, 0.2931693, -0.32815993, 0.0, 4.9231167]
# epoch 95: 100%|██| 1875/1875 [00:11<00:00, 159.10it/s, acc=1, loss=[0.01082942, 0.2930918, -0.32809797, 0.0, 4.921117]]
# epoch 96: 100%|█| 1875/1875 [00:11<00:00, 159.95it/s, acc=1, loss=[0.010852794, 0.29302013, -0.32805443, 0.0, 4.920133]
# epoch 97: 100%|█| 1875/1875 [00:11<00:00, 159.46it/s, acc=1, loss=[0.010848969, 0.29294118, -0.32799062, 0.0, 4.918317]
# epoch 98: 100%|██| 1875/1875 [00:11<00:00, 160.56it/s, acc=1, loss=[0.010845669, 0.29296747, -0.32803088, 0.0, 4.9183]]
# epoch 99: 100%|█| 1875/1875 [00:11<00:00, 159.80it/s, acc=1, loss=[0.010843193, 0.29296154, -0.32803673, 0.0, 4.9181166
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# E:\Medical Imaging Diagnostic (MID) Lab\XAI in MID\my_implementation_interpretable_CNN\my_interpretable_CNN.py in <module>
#    1115         ipython = get_ipython()
#    1116         ipython.magic("reset -f")
# -> 1117         sys.exit()
#    1118     else:
#    1119         #counterfactual_generator.load_weights(filepath=weights_path+'/counterfactual_generator_model.hdf5')
#
# NameError: name 'sys' is not defined
