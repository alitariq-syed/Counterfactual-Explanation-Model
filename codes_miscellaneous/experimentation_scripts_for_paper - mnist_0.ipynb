# %%
#%run -i my_interpretable_CNN.py --help

# %%
# for index in range(2):
#     %run -i my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f
#     %load_ext autoreload
#     %autoreload 1

# %%
# for index in range(2):
#     %run -n my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f

# %%
# %run -i my_interpretable_CNN.py --train_counterfactual_net=True --alter_class=0 --cfe_epochs=100 --l1_weight=2
# Out:
# TF version:  2.3.0
# ...GPU set_memory_growth successfully set...
# not saving log file
# save_path:  ./trained_weights/myCNN/mnist/standard
# resuming training
#
#  Namespace(alter_class=0, analyze_filter_importance=False, cfe_epochs=100, create_counterfactual_combined=True, dataset='mnist', filter_category_method='own_reduce_loss', filter_modified_directly=True, find_filter_class=False, fine_tune=False, fixed_classes=True, fixed_classes_reduce_loss=True, full_standard=True, high_capacity_model=True, imagenet_weights=False, interpretable=False, l1_weight=2.0, load_counterfactual_net=True, loss_compute=True, model='myCNN/', resume=True, resume_counterfactual_net=False, save_directory='./trained_weights/', save_filter_fmap=False, save_filter_importance=False, save_logFile=False, save_path='./trained_weights/myCNN/mnist/standard', save_top_layer=True, test=True, test_counterfactual_net=False, test_filter_importance=False, train=False, train_counterfactual_net='True', train_using_builtin_fit_method=True, visualize_fmaps=False)
#
# batch_size:  32
# not using imagenet_weights
# Model: "VGG_base_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 12, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# target_conv (Conv2D)            (None, 10, 10, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 5, 5, 128)    0           target_conv[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 128)]        0           global_average_pooling2d[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           1290        tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 10)           0           dense[0][0]
# ==================================================================================================
# Total params: 93,962
# Trainable params: 93,962
# Non-trainable params: 0
# __________________________________________________________________________________________________
# weights loaded
# Testing...
# 100%|████████████████████████████████████████████████████████| 313/313 [00:02<00:00, 147.55it/s, acc=0.983, loss=0.051]
#
# Test loss: 0.050998732
# Test accuracy: 0.9828
# l1 weight:  2.0
# training CF model for alter class:  0
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# counterfactual_model (Functiona (None, 128)          109184      input_3[0][0]
# __________________________________________________________________________________________________
# VGG_base_model (Functional)     [(None, 10), (None,  93962       input_3[0][0]
#                                                                  counterfactual_model[0][0]
# ==================================================================================================
# Total params: 110,474
# Trainable params: 16,512
# Non-trainable params: 93,962
# __________________________________________________________________________________________________
# training for fixed alter class:  0
# epoch 0: 100%|█| 1875/1875 [00:12<00:00, 150.97it/s, acc=0.827, loss=[0.7861614, 0.38599375, -0.14322418, 0.0, 6.047766
# epoch 1: 100%|█| 1875/1875 [00:11<00:00, 162.42it/s, acc=0.999, loss=[0.26730758, 0.33993375, -0.16423707, 0.0, 5.31945
# epoch 2: 100%|█| 1875/1875 [00:11<00:00, 163.96it/s, acc=0.999, loss=[0.26238477, 0.31133184, -0.16137588, 0.0, 4.87043
# epoch 3: 100%|█| 1875/1875 [00:11<00:00, 161.68it/s, acc=1, loss=[0.19664738, 0.31505126, -0.16941972, 0.0, 4.9267836]]
# epoch 4: 100%|██| 1875/1875 [00:11<00:00, 161.53it/s, acc=1, loss=[0.14462654, 0.32090166, -0.17404574, 0.0, 5.016733]]
# epoch 5: 100%|█| 1875/1875 [00:11<00:00, 161.38it/s, acc=1, loss=[0.13210498, 0.32015318, -0.17420435, 0.0, 5.0044665]]
# epoch 6: 100%|█████| 1875/1875 [00:11<00:00, 162.37it/s, acc=1, loss=[0.12594996, 0.3195896, -0.17421044, 0.0, 4.9954]]
# epoch 7: 100%|██| 1875/1875 [00:11<00:00, 160.84it/s, acc=1, loss=[0.1247666, 0.31864822, -0.17404075, 0.0, 4.9804835]]
# epoch 8: 100%|████| 1875/1875 [00:11<00:00, 161.77it/s, acc=1, loss=[0.12458167, 0.31786275, -0.17391805, 0.0, 4.9681]]
# epoch 9: 100%|█| 1875/1875 [00:11<00:00, 161.60it/s, acc=1, loss=[0.12458937, 0.31720102, -0.17381066, 0.0, 4.9576836]]
# epoch 10: 100%|██| 1875/1875 [00:11<00:00, 161.17it/s, acc=1, loss=[0.12463785, 0.31666496, -0.17371896, 0.0, 4.94925]]
# epoch 11: 100%|██| 1875/1875 [00:11<00:00, 161.32it/s, acc=1, loss=[0.12473225, 0.316189, -0.17364968, 0.0, 4.9417834]]
# epoch 12: 100%|█| 1875/1875 [00:11<00:00, 161.20it/s, acc=1, loss=[0.12492298, 0.31572697, -0.17358415, 0.0, 4.934533]]
# epoch 13: 100%|█| 1875/1875 [00:11<00:00, 161.61it/s, acc=1, loss=[0.12513612, 0.31528214, -0.17352735, 0.0, 4.927583]]
# epoch 14: 100%|█| 1875/1875 [00:11<00:00, 161.58it/s, acc=1, loss=[0.12538691, 0.31484073, -0.17346942, 0.0, 4.9206834]
# epoch 15: 100%|█| 1875/1875 [00:11<00:00, 161.81it/s, acc=1, loss=[0.12568195, 0.31442517, -0.17341363, 0.0, 4.9142165]
# epoch 16: 100%|█| 1875/1875 [00:11<00:00, 160.33it/s, acc=1, loss=[0.12606819, 0.31393158, -0.17334457, 0.0, 4.9065332]
# epoch 17: 100%|█| 1875/1875 [00:11<00:00, 161.07it/s, acc=1, loss=[0.12653431, 0.31337225, -0.17325762, 0.0, 4.8978333]
# epoch 18: 100%|██| 1875/1875 [00:11<00:00, 161.57it/s, acc=1, loss=[0.12712108, 0.31271705, -0.17314564, 0.0, 4.88765]]
# epoch 19: 100%|█| 1875/1875 [00:11<00:00, 161.84it/s, acc=1, loss=[0.1278433, 0.31193456, -0.17302388, 0.0, 4.8754835]]
# epoch 20: 100%|█████| 1875/1875 [00:11<00:00, 162.02it/s, acc=1, loss=[0.12886156, 0.31094012, -0.17285419, 0.0, 4.86]]
# epoch 21: 100%|█| 1875/1875 [00:11<00:00, 162.25it/s, acc=1, loss=[0.13003625, 0.30978608, -0.17263888, 0.0, 4.8420167]
# epoch 22: 100%|████| 1875/1875 [00:11<00:00, 159.26it/s, acc=1, loss=[0.13130048, 0.3084946, -0.17239723, 0.0, 4.8219]]
# epoch 23: 100%|█| 1875/1875 [00:11<00:00, 160.65it/s, acc=1, loss=[0.13274933, 0.30715397, -0.17211826, 0.0, 4.8009834]
# epoch 24: 100%|█| 1875/1875 [00:11<00:00, 160.66it/s, acc=1, loss=[0.13424253, 0.30571854, -0.1718148, 0.0, 4.7785835]]
# epoch 25: 100%|█| 1875/1875 [00:11<00:00, 162.69it/s, acc=1, loss=[0.13555425, 0.3044338, -0.17152819, 0.0, 4.7585335]]
# epoch 26: 100%|██| 1875/1875 [00:11<00:00, 162.15it/s, acc=1, loss=[0.13674851, 0.30322486, -0.17127506, 0.0, 4.73965]]
# epoch 27: 100%|██| 1875/1875 [00:11<00:00, 162.15it/s, acc=1, loss=[0.13751155, 0.30240977, -0.1711118, 0.0, 4.726917]]
# epoch 28: 100%|█| 1875/1875 [00:11<00:00, 161.44it/s, acc=1, loss=[0.13818167, 0.30169478, -0.17095569, 0.0, 4.7157335]
# epoch 29: 100%|█| 1875/1875 [00:11<00:00, 162.87it/s, acc=1, loss=[0.13867658, 0.3011706, -0.17084515, 0.0, 4.7075334]]
# epoch 30: 100%|██| 1875/1875 [00:11<00:00, 162.32it/s, acc=1, loss=[0.1390383, 0.30079618, -0.17076212, 0.0, 4.701667]]
# epoch 31: 100%|██| 1875/1875 [00:11<00:00, 162.25it/s, acc=1, loss=[0.13928837, 0.30050564, -0.1707044, 0.0, 4.697117]]
# epoch 32: 100%|█| 1875/1875 [00:11<00:00, 161.35it/s, acc=1, loss=[0.13955374, 0.30020905, -0.17064112, 0.0, 4.6924667]
# epoch 33: 100%|███| 1875/1875 [00:11<00:00, 161.72it/s, acc=1, loss=[0.13970965, 0.30000073, -0.17060319, 0.0, 4.6892]]
# epoch 34: 100%|█| 1875/1875 [00:11<00:00, 164.17it/s, acc=1, loss=[0.13979883, 0.29983932, -0.17057742, 0.0, 4.6866665]
# epoch 35: 100%|█| 1875/1875 [00:11<00:00, 162.95it/s, acc=1, loss=[0.13974252, 0.29982173, -0.17058496, 0.0, 4.6863832]
# epoch 36: 100%|███| 1875/1875 [00:11<00:00, 162.87it/s, acc=1, loss=[0.1397722, 0.29973054, -0.17057681, 0.0, 4.68495]]
# epoch 37: 100%|█| 1875/1875 [00:11<00:00, 163.26it/s, acc=1, loss=[0.13982609, 0.2996236, -0.17056186, 0.0, 4.6832666]]
# epoch 38: 100%|█| 1875/1875 [00:11<00:00, 163.02it/s, acc=1, loss=[0.13976733, 0.29962856, -0.17056903, 0.0, 4.6833334]
# epoch 39: 100%|███| 1875/1875 [00:11<00:00, 164.23it/s, acc=1, loss=[0.13971125, 0.29961422, -0.17058039, 0.0, 4.6831]]
# epoch 40: 100%|█| 1875/1875 [00:11<00:00, 163.43it/s, acc=1, loss=[0.13965137, 0.29961592, -0.17059295, 0.0, 4.6831164]
# epoch 41: 100%|███| 1875/1875 [00:11<00:00, 162.46it/s, acc=1, loss=[0.13963398, 0.29957372, -0.1705926, 0.0, 4.68245]]
# epoch 42: 100%|██| 1875/1875 [00:11<00:00, 162.06it/s, acc=1, loss=[0.139557, 0.29958925, -0.17060812, 0.0, 4.6826835]]
# epoch 43: 100%|█| 1875/1875 [00:11<00:00, 164.19it/s, acc=1, loss=[0.13962863, 0.29947472, -0.17059067, 0.0, 4.6808834]
# epoch 44: 100%|█| 1875/1875 [00:11<00:00, 159.62it/s, acc=1, loss=[0.13959083, 0.29947832, -0.17059942, 0.0, 4.6809335]
# epoch 45: 100%|█| 1875/1875 [00:11<00:00, 163.88it/s, acc=1, loss=[0.13953681, 0.2994822, -0.17060697, 0.0, 4.6809835]]
# epoch 46: 100%|███| 1875/1875 [00:11<00:00, 163.12it/s, acc=1, loss=[0.13955547, 0.29941347, -0.17060119, 0.0, 4.6799]]
# epoch 47: 100%|███| 1875/1875 [00:11<00:00, 163.46it/s, acc=1, loss=[0.13952287, 0.29939482, -0.17060755, 0.0, 4.6796]]
# epoch 48: 100%|█| 1875/1875 [00:11<00:00, 163.23it/s, acc=1, loss=[0.13948928, 0.29937688, -0.17061278, 0.0, 4.6793165]
# epoch 49: 100%|██| 1875/1875 [00:11<00:00, 160.38it/s, acc=1, loss=[0.13943905, 0.29937956, -0.17062224, 0.0, 4.67935]]
# epoch 50: 100%|█| 1875/1875 [00:11<00:00, 161.41it/s, acc=1, loss=[0.13944083, 0.29932675, -0.17062011, 0.0, 4.678517]]
# epoch 51: 100%|██████| 1875/1875 [00:11<00:00, 161.34it/s, acc=1, loss=[0.1393801, 0.2993389, -0.1706333, 0.0, 4.6787]]
# epoch 52: 100%|█| 1875/1875 [00:11<00:00, 163.76it/s, acc=1, loss=[0.13935703, 0.29933393, -0.17063792, 0.0, 4.6786165]
# epoch 53: 100%|█| 1875/1875 [00:11<00:00, 162.74it/s, acc=1, loss=[0.13931522, 0.29934096, -0.17064531, 0.0, 4.6787167]
# epoch 54: 100%|█| 1875/1875 [00:11<00:00, 162.90it/s, acc=1, loss=[0.13932805, 0.29928762, -0.17064165, 0.0, 4.677883]]
# epoch 55: 100%|██| 1875/1875 [00:11<00:00, 163.79it/s, acc=1, loss=[0.13923755, 0.2993229, -0.1706608, 0.0, 4.6784334]]
# epoch 56: 100%|██| 1875/1875 [00:11<00:00, 163.82it/s, acc=1, loss=[0.13926126, 0.29926616, -0.1706545, 0.0, 4.677533]]
# epoch 57: 100%|██| 1875/1875 [00:11<00:00, 162.06it/s, acc=1, loss=[0.1391379, 0.29933372, -0.17067899, 0.0, 4.678583]]
# epoch 58: 100%|███| 1875/1875 [00:11<00:00, 162.66it/s, acc=1, loss=[0.13916698, 0.29927102, -0.17067096, 0.0, 4.6776]]
# epoch 59: 100%|█| 1875/1875 [00:11<00:00, 163.96it/s, acc=1, loss=[0.13907002, 0.29932165, -0.17069146, 0.0, 4.6783834]
# epoch 60: 100%|█| 1875/1875 [00:11<00:00, 162.00it/s, acc=1, loss=[0.13906595, 0.29930568, -0.17069145, 0.0, 4.6781335]
# epoch 61: 100%|██| 1875/1875 [00:11<00:00, 163.73it/s, acc=1, loss=[0.1390445, 0.2993031, -0.17069596, 0.0, 4.6780834]]
# epoch 62: 100%|█| 1875/1875 [00:11<00:00, 162.62it/s, acc=1, loss=[0.13899486, 0.29929873, -0.17070574, 0.0, 4.6780167]
# epoch 63: 100%|████| 1875/1875 [00:11<00:00, 163.70it/s, acc=1, loss=[0.13892473, 0.2993047, -0.17071834, 0.0, 4.6781]]
# epoch 64: 100%|██| 1875/1875 [00:11<00:00, 162.97it/s, acc=1, loss=[0.13886651, 0.2993322, -0.17073007, 0.0, 4.678517]]
# epoch 65: 100%|█| 1875/1875 [00:12<00:00, 156.20it/s, acc=1, loss=[0.13888842, 0.2992682, -0.17072381, 0.0, 4.6775165]]
# epoch 66: 100%|██| 1875/1875 [00:11<00:00, 156.70it/s, acc=1, loss=[0.13878812, 0.29933432, -0.17074323, 0.0, 4.67855]]
# epoch 67: 100%|█| 1875/1875 [00:11<00:00, 161.73it/s, acc=1, loss=[0.13877736, 0.29931355, -0.17074609, 0.0, 4.6782165]
# epoch 68: 100%|███| 1875/1875 [00:11<00:00, 157.44it/s, acc=1, loss=[0.13873973, 0.29931918, -0.17075425, 0.0, 4.6783]]
# epoch 69: 100%|████| 1875/1875 [00:11<00:00, 159.61it/s, acc=1, loss=[0.13872197, 0.2993133, -0.17076048, 0.0, 4.6782]]
# epoch 70: 100%|█| 1875/1875 [00:11<00:00, 159.80it/s, acc=1, loss=[0.13870622, 0.2992955, -0.17076339, 0.0, 4.6779165]]
# epoch 71: 100%|███| 1875/1875 [00:11<00:00, 158.60it/s, acc=1, loss=[0.13865058, 0.2993105, -0.17077436, 0.0, 4.67815]]
# epoch 72: 100%|█| 1875/1875 [00:11<00:00, 160.61it/s, acc=1, loss=[0.13866422, 0.2992774, -0.17077048, 0.0, 4.6776333]]
# epoch 73: 100%|██| 1875/1875 [00:11<00:00, 162.78it/s, acc=1, loss=[0.13863833, 0.29926747, -0.1707755, 0.0, 4.677467]]
# epoch 74: 100%|████| 1875/1875 [00:11<00:00, 162.31it/s, acc=1, loss=[0.13854982, 0.2993084, -0.17079376, 0.0, 4.6781]]
# epoch 75: 100%|███| 1875/1875 [00:11<00:00, 162.44it/s, acc=1, loss=[0.13857457, 0.29925725, -0.17078902, 0.0, 4.6773]]
# epoch 76: 100%|███| 1875/1875 [00:11<00:00, 162.87it/s, acc=1, loss=[0.1385165, 0.29928637, -0.17080243, 0.0, 4.67775]]
# epoch 77: 100%|█| 1875/1875 [00:11<00:00, 163.18it/s, acc=1, loss=[0.13846828, 0.2993037, -0.17080888, 0.0, 4.6780167]]
# epoch 78: 100%|█| 1875/1875 [00:11<00:00, 162.89it/s, acc=1, loss=[0.1384469, 0.29929444, -0.17081477, 0.0, 4.6778665]]
# epoch 79: 100%|█| 1875/1875 [00:11<00:00, 163.40it/s, acc=1, loss=[0.1384193, 0.29930103, -0.17081739, 0.0, 4.6779666]]
# epoch 80: 100%|██| 1875/1875 [00:11<00:00, 163.44it/s, acc=1, loss=[0.13840543, 0.2992864, -0.1708189, 0.0, 4.6777334]]
# epoch 81: 100%|█| 1875/1875 [00:11<00:00, 163.64it/s, acc=1, loss=[0.13840608, 0.29926386, -0.17081885, 0.0, 4.6773834]
# epoch 82: 100%|█| 1875/1875 [00:11<00:00, 163.41it/s, acc=1, loss=[0.1383623, 0.29928017, -0.17082793, 0.0, 4.6776333]]
# epoch 83: 100%|██| 1875/1875 [00:11<00:00, 161.73it/s, acc=1, loss=[0.13835682, 0.29926258, -0.17082933, 0.0, 4.67735]]
# epoch 84: 100%|█| 1875/1875 [00:11<00:00, 159.76it/s, acc=1, loss=[0.13831358, 0.29927114, -0.17083898, 0.0, 4.6774836]
# epoch 85: 100%|█| 1875/1875 [00:11<00:00, 163.11it/s, acc=1, loss=[0.13826232, 0.29928395, -0.17084846, 0.0, 4.6776834]
# epoch 86: 100%|██| 1875/1875 [00:11<00:00, 160.06it/s, acc=1, loss=[0.13819252, 0.29931405, -0.17086314, 0.0, 4.67815]]
# epoch 87: 100%|█| 1875/1875 [00:11<00:00, 162.65it/s, acc=1, loss=[0.13815694, 0.29929924, -0.17087005, 0.0, 4.6779165]
# epoch 88: 100%|██| 1875/1875 [00:11<00:00, 158.42it/s, acc=1, loss=[0.13817576, 0.2992561, -0.17086594, 0.0, 4.677233]]
# epoch 89: 100%|██| 1875/1875 [00:11<00:00, 165.71it/s, acc=1, loss=[0.13803062, 0.29935953, -0.17089334, 0.0, 4.67885]]
# epoch 90: 100%|█████| 1875/1875 [00:11<00:00, 160.44it/s, acc=1, loss=[0.1379857, 0.29936263, -0.1709009, 0.0, 4.6789]]
# epoch 91: 100%|█| 1875/1875 [00:11<00:00, 164.57it/s, acc=1, loss=[0.13795744, 0.29937494, -0.17090833, 0.0, 4.6790833]
# epoch 92: 100%|████| 1875/1875 [00:11<00:00, 164.11it/s, acc=1, loss=[0.13793387, 0.2993758, -0.17091401, 0.0, 4.6791]]
# epoch 93: 100%|██| 1875/1875 [00:11<00:00, 165.06it/s, acc=1, loss=[0.13789073, 0.2993806, -0.17092471, 0.0, 4.679167]]
# epoch 94: 100%|█| 1875/1875 [00:11<00:00, 164.36it/s, acc=1, loss=[0.1378153, 0.29942212, -0.17093995, 0.0, 4.6798167]]
# epoch 95: 100%|██| 1875/1875 [00:11<00:00, 166.19it/s, acc=1, loss=[0.13776602, 0.2994515, -0.17095166, 0.0, 4.680267]]
# epoch 96: 100%|████| 1875/1875 [00:11<00:00, 167.34it/s, acc=1, loss=[0.13777687, 0.2994151, -0.17094922, 0.0, 4.6797]]
# epoch 97: 100%|█████| 1875/1875 [00:11<00:00, 166.58it/s, acc=1, loss=[0.13771857, 0.299441, -0.17096137, 0.0, 4.6801]]
# epoch 98: 100%|███| 1875/1875 [00:11<00:00, 160.71it/s, acc=1, loss=[0.1376692, 0.29946324, -0.17097177, 0.0, 4.68045]]
# epoch 99: 100%|█| 1875/1875 [00:11<00:00, 169.37it/s, acc=1, loss=[0.13767315, 0.2994401, -0.17097087, 0.0, 4.6800833]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# E:\Medical Imaging Diagnostic (MID) Lab\XAI in MID\my_implementation_interpretable_CNN\my_interpretable_CNN.py in <module>
#    1073         ipython = get_ipython()
#    1074         ipython.magic("reset -f")
# -> 1075         sys.exit()
#    1076     else:
#    1077         #counterfactual_generator.load_weights(filepath=weights_path+'/counterfactual_generator_model.hdf5')
#
# NameError: name 'sys' is not defined

# %%
#retrain with threshold = 0.5
# %run -i my_interpretable_CNN.py --train_counterfactual_net=True --alter_class=0 --cfe_epochs=100 --l1_weight=2
# Out:
# TF version:  2.3.0
# ...GPU set_memory_growth successfully set...
# not saving log file
# save_path:  ./trained_weights/myCNN/mnist/standard
# resuming training
#
#  Namespace(alter_class=0, analyze_filter_importance=False, cfe_epochs=100, create_counterfactual_combined=True, dataset='mnist', filter_category_method='own_reduce_loss', filter_modified_directly=True, find_filter_class=False, fine_tune=False, fixed_classes=True, fixed_classes_reduce_loss=True, full_standard=True, high_capacity_model=True, imagenet_weights=False, interpretable=False, l1_weight=2.0, load_counterfactual_net=True, loss_compute=True, model='myCNN/', resume=True, resume_counterfactual_net=False, save_directory='./trained_weights/', save_filter_fmap=False, save_filter_importance=False, save_logFile=False, save_path='./trained_weights/myCNN/mnist/standard', save_top_layer=True, test=True, test_counterfactual_net=False, test_filter_importance=False, train=False, train_counterfactual_net='True', train_using_builtin_fit_method=True, visualize_fmaps=False)
#
# batch_size:  32
# not using imagenet_weights
# Model: "VGG_base_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 12, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# target_conv (Conv2D)            (None, 10, 10, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 5, 5, 128)    0           target_conv[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 128)]        0           global_average_pooling2d[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           1290        tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 10)           0           dense[0][0]
# ==================================================================================================
# Total params: 93,962
# Trainable params: 93,962
# Non-trainable params: 0
# __________________________________________________________________________________________________
# weights loaded
# Testing...
# 100%|████████████████████████████████████████████████████████| 313/313 [00:02<00:00, 151.89it/s, acc=0.983, loss=0.051]
#
# Test loss: 0.050998703
# Test accuracy: 0.9828
# threshold:  0.5
# l1 weight:  2.0
# training CF model for alter class:  0
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# counterfactual_model (Functiona (None, 128)          109184      input_3[0][0]
# __________________________________________________________________________________________________
# VGG_base_model (Functional)     [(None, 10), (None,  93962       input_3[0][0]
#                                                                  counterfactual_model[0][0]
# ==================================================================================================
# Total params: 110,474
# Trainable params: 16,512
# Non-trainable params: 93,962
# __________________________________________________________________________________________________
# training for fixed alter class:  0
# epoch 0: 100%|█| 1875/1875 [00:12<00:00, 155.37it/s, acc=0.997, loss=[0.055606414, 0.49871275, -0.24151213, 0.0, 8.3996
# epoch 1: 100%|█| 1875/1875 [00:11<00:00, 168.31it/s, acc=1, loss=[0.054833096, 0.32851258, -0.21797131, 0.0, 5.4199667]
# epoch 2: 100%|███| 1875/1875 [00:11<00:00, 168.53it/s, acc=1, loss=[0.054777592, 0.32135656, -0.21742561, 0.0, 5.3428]]
# epoch 3: 100%|███| 1875/1875 [00:11<00:00, 167.91it/s, acc=1, loss=[0.05243631, 0.3206659, -0.21818478, 0.0, 5.378267]]
# epoch 4: 100%|█| 1875/1875 [00:11<00:00, 167.13it/s, acc=1, loss=[0.051409375, 0.32000333, -0.21881197, 0.0, 5.3508334]
# epoch 5: 100%|██| 1875/1875 [00:11<00:00, 165.84it/s, acc=1, loss=[0.051063623, 0.3192626, -0.21904372, 0.0, 5.320433]]
# epoch 6: 100%|███| 1875/1875 [00:11<00:00, 167.80it/s, acc=1, loss=[0.050826713, 0.31883934, -0.2192131, 0.0, 5.30085]]
# epoch 7: 100%|█████| 1875/1875 [00:11<00:00, 168.17it/s, acc=1, loss=[0.0507587, 0.31842265, -0.21926464, 0.0, 5.2853]]
# epoch 8: 100%|██| 1875/1875 [00:11<00:00, 167.52it/s, acc=1, loss=[0.050749462, 0.31800967, -0.21926549, 0.0, 5.27105]]
# epoch 9: 100%|█| 1875/1875 [00:11<00:00, 167.82it/s, acc=1, loss=[0.05059717, 0.31787235, -0.21933915, 0.0, 5.2631335]]
# epoch 10: 100%|█| 1875/1875 [00:11<00:00, 167.31it/s, acc=1, loss=[0.050601788, 0.3175332, -0.21927838, 0.0, 5.2537165]
# epoch 11: 100%|█| 1875/1875 [00:11<00:00, 167.14it/s, acc=1, loss=[0.050485045, 0.31742424, -0.21932742, 0.0, 5.2472835
# epoch 12: 100%|█| 1875/1875 [00:11<00:00, 165.17it/s, acc=1, loss=[0.050468262, 0.3171961, -0.21926896, 0.0, 5.2404833]
# epoch 13: 100%|██| 1875/1875 [00:11<00:00, 162.89it/s, acc=1, loss=[0.05041995, 0.31705546, -0.21924397, 0.0, 5.23585]]
# epoch 14: 100%|██| 1875/1875 [00:11<00:00, 169.37it/s, acc=1, loss=[0.050347947, 0.3169697, -0.21925701, 0.0, 5.23165]]
# epoch 15: 100%|█| 1875/1875 [00:11<00:00, 169.81it/s, acc=1, loss=[0.050347503, 0.31678537, -0.21921542, 0.0, 5.2257833
# epoch 16: 100%|█| 1875/1875 [00:11<00:00, 169.48it/s, acc=1, loss=[0.050271187, 0.31671587, -0.2192037, 0.0, 5.2226834]
# epoch 17: 100%|█████| 1875/1875 [00:11<00:00, 170.00it/s, acc=1, loss=[0.0502925, 0.31655332, -0.2191488, 0.0, 5.2176]]
# epoch 18: 100%|█| 1875/1875 [00:11<00:00, 161.75it/s, acc=1, loss=[0.0503016, 0.31641552, -0.21911159, 0.0, 5.2133164]]
# epoch 19: 100%|██| 1875/1875 [00:11<00:00, 162.28it/s, acc=1, loss=[0.05029454, 0.3163235, -0.21910238, 0.0, 5.209133]]
# epoch 20: 100%|███| 1875/1875 [00:11<00:00, 167.81it/s, acc=1, loss=[0.0503221, 0.31617996, -0.21904705, 0.0, 5.20495]]
# epoch 21: 100%|██| 1875/1875 [00:11<00:00, 167.90it/s, acc=1, loss=[0.050305996, 0.3161165, -0.21905363, 0.0, 5.20155]]
# epoch 22: 100%|█| 1875/1875 [00:11<00:00, 168.53it/s, acc=1, loss=[0.050320197, 0.31600392, -0.21901366, 0.0, 5.197933]
# epoch 23: 100%|█| 1875/1875 [00:11<00:00, 164.68it/s, acc=1, loss=[0.0502919, 0.31596467, -0.21902615, 0.0, 5.1955166]]
# epoch 24: 100%|█| 1875/1875 [00:11<00:00, 167.91it/s, acc=1, loss=[0.050302587, 0.31586772, -0.21899685, 0.0, 5.19175]]
# epoch 25: 100%|███| 1875/1875 [00:11<00:00, 166.56it/s, acc=1, loss=[0.05034874, 0.31576455, -0.2189545, 0.0, 5.18875]]
# epoch 26: 100%|█| 1875/1875 [00:11<00:00, 168.47it/s, acc=1, loss=[0.05036394, 0.3156864, -0.21894392, 0.0, 5.1856666]]
# epoch 27: 100%|█| 1875/1875 [00:11<00:00, 168.05it/s, acc=1, loss=[0.050366193, 0.31564766, -0.21893083, 0.0, 5.183533]
# epoch 28: 100%|█| 1875/1875 [00:11<00:00, 169.82it/s, acc=1, loss=[0.05037958, 0.31556514, -0.21890464, 0.0, 5.1806335]
# epoch 29: 100%|█| 1875/1875 [00:11<00:00, 163.63it/s, acc=1, loss=[0.050377104, 0.3155164, -0.21892568, 0.0, 5.177883]]
# epoch 30: 100%|█| 1875/1875 [00:11<00:00, 168.37it/s, acc=1, loss=[0.050359238, 0.31548578, -0.218903, 0.0, 5.1766167]]
# epoch 31: 100%|█| 1875/1875 [00:11<00:00, 168.36it/s, acc=1, loss=[0.050394572, 0.31540197, -0.21890305, 0.0, 5.173033]
# epoch 32: 100%|█| 1875/1875 [00:11<00:00, 167.84it/s, acc=1, loss=[0.05039741, 0.3153544, -0.21889079, 0.0, 5.1713166]]
# epoch 33: 100%|█| 1875/1875 [00:11<00:00, 168.50it/s, acc=1, loss=[0.050374668, 0.31534815, -0.21889243, 0.0, 5.1701665
# epoch 34: 100%|███| 1875/1875 [00:11<00:00, 168.86it/s, acc=1, loss=[0.05040977, 0.3152585, -0.21889468, 0.0, 5.16705]]
# epoch 35: 100%|█| 1875/1875 [00:11<00:00, 169.23it/s, acc=1, loss=[0.050424818, 0.31520742, -0.21885109, 0.0, 5.165517]
# epoch 36: 100%|█████| 1875/1875 [00:11<00:00, 169.30it/s, acc=1, loss=[0.05045209, 0.3151302, -0.2188448, 0.0, 5.1629]]
# epoch 37: 100%|█| 1875/1875 [00:11<00:00, 168.86it/s, acc=1, loss=[0.05039595, 0.31516775, -0.21888031, 0.0, 5.162783]]
# epoch 38: 100%|███| 1875/1875 [00:11<00:00, 169.45it/s, acc=1, loss=[0.05040363, 0.3151113, -0.21884683, 0.0, 5.16125]]
# epoch 39: 100%|█| 1875/1875 [00:11<00:00, 168.51it/s, acc=1, loss=[0.050417643, 0.3150929, -0.21886101, 0.0, 5.1593666]
# epoch 40: 100%|█| 1875/1875 [00:11<00:00, 166.13it/s, acc=1, loss=[0.05039912, 0.31506652, -0.21886702, 0.0, 5.1581335]
# epoch 41: 100%|█| 1875/1875 [00:11<00:00, 162.76it/s, acc=1, loss=[0.05041049, 0.31503597, -0.21884565, 0.0, 5.1566334]
# epoch 42: 100%|███| 1875/1875 [00:11<00:00, 163.71it/s, acc=1, loss=[0.05043977, 0.31496868, -0.21882756, 0.0, 5.1549]]
# epoch 43: 100%|█| 1875/1875 [00:11<00:00, 167.16it/s, acc=1, loss=[0.0504475, 0.31493494, -0.21882987, 0.0, 5.1531835]]
# epoch 44: 100%|█| 1875/1875 [00:11<00:00, 168.27it/s, acc=1, loss=[0.050441947, 0.31492102, -0.21883492, 0.0, 5.15235]]
# epoch 45: 100%|█| 1875/1875 [00:11<00:00, 168.99it/s, acc=1, loss=[0.050452877, 0.31489307, -0.2188181, 0.0, 5.150833]]
# epoch 46: 100%|█| 1875/1875 [00:11<00:00, 169.41it/s, acc=1, loss=[0.050454818, 0.31485873, -0.21882455, 0.0, 5.1496334
# epoch 47: 100%|█| 1875/1875 [00:11<00:00, 169.27it/s, acc=1, loss=[0.05048186, 0.31481984, -0.21882483, 0.0, 5.1482167]
# epoch 48: 100%|█| 1875/1875 [00:11<00:00, 169.64it/s, acc=1, loss=[0.050460383, 0.31481126, -0.21881323, 0.0, 5.1474667
# epoch 49: 100%|█| 1875/1875 [00:10<00:00, 170.80it/s, acc=1, loss=[0.05046275, 0.31479105, -0.2188108, 0.0, 5.1465836]]
# epoch 50: 100%|██| 1875/1875 [00:11<00:00, 170.41it/s, acc=1, loss=[0.050473724, 0.31475806, -0.21880513, 0.0, 5.1454]]
# epoch 51: 100%|█| 1875/1875 [00:11<00:00, 170.26it/s, acc=1, loss=[0.050520957, 0.31467342, -0.21876527, 0.0, 5.1434665
# epoch 52: 100%|█| 1875/1875 [00:11<00:00, 168.56it/s, acc=1, loss=[0.050481535, 0.31470373, -0.21878336, 0.0, 5.143133]
# epoch 53: 100%|██| 1875/1875 [00:11<00:00, 170.30it/s, acc=1, loss=[0.05048935, 0.31467202, -0.218796, 0.0, 5.1418667]]
# epoch 54: 100%|███| 1875/1875 [00:11<00:00, 169.65it/s, acc=1, loss=[0.0504879, 0.31465843, -0.21877727, 0.0, 5.14145]]
# epoch 55: 100%|█| 1875/1875 [00:11<00:00, 169.78it/s, acc=1, loss=[0.05048856, 0.31463462, -0.21878263, 0.0, 5.1405168]
# epoch 56: 100%|█| 1875/1875 [00:11<00:00, 169.30it/s, acc=1, loss=[0.050497327, 0.31462932, -0.21883254, 0.0, 5.14005]]
# epoch 57: 100%|█| 1875/1875 [00:11<00:00, 169.64it/s, acc=1, loss=[0.05003298, 0.31586125, -0.2202606, 0.0, 5.1703835]]
# epoch 58: 100%|███| 1875/1875 [00:10<00:00, 170.63it/s, acc=1, loss=[0.046394758, 0.32374993, -0.2282856, 0.0, 5.3396]]
# epoch 59: 100%|██| 1875/1875 [00:11<00:00, 169.71it/s, acc=1, loss=[0.045444094, 0.32466868, -0.22933717, 0.0, 5.3465]]
# epoch 60: 100%|█| 1875/1875 [00:10<00:00, 170.68it/s, acc=1, loss=[0.045081303, 0.32479772, -0.22957137, 0.0, 5.3429165
# epoch 61: 100%|███| 1875/1875 [00:11<00:00, 170.00it/s, acc=1, loss=[0.044904336, 0.3247528, -0.229589, 0.0, 5.339617]]
# epoch 62: 100%|█| 1875/1875 [00:10<00:00, 170.59it/s, acc=1, loss=[0.044803895, 0.32475433, -0.22960097, 0.0, 5.3367667
# epoch 63: 100%|█| 1875/1875 [00:11<00:00, 169.90it/s, acc=1, loss=[0.044731617, 0.32469392, -0.22958694, 0.0, 5.3332334
# epoch 64: 100%|█| 1875/1875 [00:10<00:00, 170.70it/s, acc=1, loss=[0.044714678, 0.32459936, -0.22955598, 0.0, 5.3286166
# epoch 65: 100%|██| 1875/1875 [00:11<00:00, 168.33it/s, acc=1, loss=[0.04463872, 0.32463282, -0.22956643, 0.0, 5.32775]]
# epoch 66: 100%|█| 1875/1875 [00:11<00:00, 169.97it/s, acc=1, loss=[0.044619706, 0.32459337, -0.22955531, 0.0, 5.3249335
# epoch 67: 100%|█| 1875/1875 [00:10<00:00, 170.53it/s, acc=1, loss=[0.044554498, 0.32460365, -0.22955358, 0.0, 5.3237667
# epoch 68: 100%|█| 1875/1875 [00:11<00:00, 169.38it/s, acc=1, loss=[0.04453483, 0.32456377, -0.22953668, 0.0, 5.3220167]
# epoch 69: 100%|███| 1875/1875 [00:11<00:00, 166.93it/s, acc=1, loss=[0.04453607, 0.32450733, -0.22952023, 0.0, 5.3191]]
# epoch 70: 100%|█| 1875/1875 [00:11<00:00, 170.21it/s, acc=1, loss=[0.044466875, 0.32454643, -0.22954424, 0.0, 5.319033]
# epoch 71: 100%|██| 1875/1875 [00:11<00:00, 170.45it/s, acc=1, loss=[0.04452096, 0.32441208, -0.22947523, 0.0, 5.31565]]
# epoch 72: 100%|█| 1875/1875 [00:11<00:00, 164.88it/s, acc=1, loss=[0.044423908, 0.3245265, -0.2295154, 0.0, 5.3167834]]
# epoch 73: 100%|██| 1875/1875 [00:11<00:00, 166.78it/s, acc=1, loss=[0.044417467, 0.3244769, -0.2295067, 0.0, 5.314433]]
# epoch 74: 100%|█| 1875/1875 [00:11<00:00, 170.16it/s, acc=1, loss=[0.044405073, 0.32444674, -0.2294929, 0.0, 5.313017]]
# epoch 75: 100%|█| 1875/1875 [00:11<00:00, 169.26it/s, acc=1, loss=[0.04440781, 0.32439896, -0.22946566, 0.0, 5.3113666]
# epoch 76: 100%|█| 1875/1875 [00:11<00:00, 169.56it/s, acc=1, loss=[0.044398535, 0.32438648, -0.22946559, 0.0, 5.309933]
# epoch 77: 100%|██| 1875/1875 [00:10<00:00, 170.54it/s, acc=1, loss=[0.04437477, 0.3243868, -0.22947119, 0.0, 5.309117]]
# epoch 78: 100%|████| 1875/1875 [00:11<00:00, 169.06it/s, acc=1, loss=[0.04438007, 0.32435885, -0.22945218, 0.0, 5.308]]
# epoch 79: 100%|█| 1875/1875 [00:11<00:00, 169.08it/s, acc=1, loss=[0.04436369, 0.32435957, -0.22945419, 0.0, 5.307317]]
# epoch 80: 100%|█| 1875/1875 [00:11<00:00, 168.87it/s, acc=1, loss=[0.044345215, 0.3243446, -0.2294512, 0.0, 5.3058667]]
# epoch 81: 100%|█| 1875/1875 [00:11<00:00, 170.23it/s, acc=1, loss=[0.044371855, 0.32430336, -0.22943842, 0.0, 5.3044333
# epoch 82: 100%|█| 1875/1875 [00:11<00:00, 170.17it/s, acc=1, loss=[0.044368546, 0.32427457, -0.22941747, 0.0, 5.3029833
# epoch 83: 100%|█| 1875/1875 [00:11<00:00, 169.56it/s, acc=1, loss=[0.044357043, 0.32427305, -0.22943476, 0.0, 5.302183]
# epoch 84: 100%|██| 1875/1875 [00:11<00:00, 164.11it/s, acc=1, loss=[0.044353068, 0.3242701, -0.22943504, 0.0, 5.30155]]
# epoch 85: 100%|██| 1875/1875 [00:11<00:00, 168.83it/s, acc=1, loss=[0.044393077, 0.32421744, -0.22939609, 0.0, 5.3004]]
# epoch 86: 100%|██| 1875/1875 [00:11<00:00, 169.75it/s, acc=1, loss=[0.044382036, 0.32416648, -0.22938623, 0.0, 5.2983]]
# epoch 87: 100%|█| 1875/1875 [00:11<00:00, 169.74it/s, acc=1, loss=[0.044360865, 0.32418993, -0.22939742, 0.0, 5.29855]]
# epoch 88: 100%|█| 1875/1875 [00:11<00:00, 169.96it/s, acc=1, loss=[0.04437142, 0.32418022, -0.22940587, 0.0, 5.2972665]
# epoch 89: 100%|█| 1875/1875 [00:10<00:00, 170.54it/s, acc=1, loss=[0.04435662, 0.32414892, -0.22938257, 0.0, 5.296467]]
# epoch 90: 100%|█| 1875/1875 [00:11<00:00, 170.42it/s, acc=1, loss=[0.044366598, 0.3241106, -0.22936638, 0.0, 5.2950335]
# epoch 91: 100%|█| 1875/1875 [00:11<00:00, 169.98it/s, acc=1, loss=[0.044355422, 0.32415208, -0.22938892, 0.0, 5.29505]]
# epoch 92: 100%|██| 1875/1875 [00:11<00:00, 170.21it/s, acc=1, loss=[0.044365894, 0.32410514, -0.22937472, 0.0, 5.2934]]
# epoch 93: 100%|█| 1875/1875 [00:11<00:00, 169.75it/s, acc=1, loss=[0.044360932, 0.32410958, -0.22938728, 0.0, 5.292917]
# epoch 94: 100%|█| 1875/1875 [00:11<00:00, 169.84it/s, acc=1, loss=[0.044353094, 0.32409835, -0.22937782, 0.0, 5.2924833
# epoch 95: 100%|█| 1875/1875 [00:10<00:00, 170.60it/s, acc=1, loss=[0.044365607, 0.32406232, -0.22936322, 0.0, 5.291333]
# epoch 96: 100%|█| 1875/1875 [00:11<00:00, 170.18it/s, acc=1, loss=[0.04434303, 0.32408646, -0.22938037, 0.0, 5.2912664]
# epoch 97: 100%|█| 1875/1875 [00:11<00:00, 169.83it/s, acc=1, loss=[0.044335697, 0.32405975, -0.2293767, 0.0, 5.2903666]
# epoch 98: 100%|█| 1875/1875 [00:11<00:00, 170.26it/s, acc=1, loss=[0.044356726, 0.3240301, -0.22935776, 0.0, 5.2891335]
# epoch 99: 100%|█| 1875/1875 [00:10<00:00, 170.65it/s, acc=1, loss=[0.044319496, 0.32409596, -0.2293896, 0.0, 5.2903666]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# E:\Medical Imaging Diagnostic (MID) Lab\XAI in MID\my_implementation_interpretable_CNN\my_interpretable_CNN.py in <module>
#    1103         ipython = get_ipython()
#    1104         ipython.magic("reset -f")
# -> 1105         sys.exit()
#    1106     else:
#    1107         #counterfactual_generator.load_weights(filepath=weights_path+'/counterfactual_generator_model.hdf5')
#
# NameError: name 'sys' is not defined
