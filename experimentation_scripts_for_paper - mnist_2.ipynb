# %%
#%run -i my_interpretable_CNN.py --help

# %%
# for index in range(2):
#     %run -i my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f
#     %load_ext autoreload
#     %autoreload 1

# %%
# for index in range(2):
#     %run -n my_interpretable_CNN.py --alter_class=$index --cfe_epochs=1 --save_logFile=True
#     #%reset -f

# %%
#retrain with threshold = 0.5
# %run -i my_interpretable_CNN.py --train_counterfactual_net=True --alter_class=2 --cfe_epochs=100 --l1_weight=2
# Out:
# TF version:  2.3.0
# ...GPU set_memory_growth successfully set...
# not saving log file
# save_path:  ./trained_weights/myCNN/mnist/standard
# resuming training
#
#  Namespace(alter_class=2, alter_class_2=5, analysis_class=5, analyze_filter_importance=False, cfe_epochs=100, counterfactual_PP=True, create_counterfactual_combined=True, dataset='mnist', filter_category_method='own_reduce_loss', filter_modified_directly=True, find_filter_class=False, find_global_filters=False, fine_tune=False, fixed_classes=True, fixed_classes_reduce_loss=True, full_standard=True, high_capacity_model=True, imagenet_weights=False, interpretable=False, l1_weight=2.0, load_counterfactual_net=True, loss_compute=True, model='myCNN/', resume=True, resume_counterfactual_net=False, save_directory='./trained_weights/', save_filter_fmap=False, save_filter_importance=False, save_logFile=False, save_path='./trained_weights/myCNN/mnist/standard', save_top_layer=True, test=False, test_counterfactual_net=False, test_filter_importance=False, train=False, train_counterfactual_net='True', train_using_builtin_fit_method=True, visualize_fmaps=False)
#
# batch_size:  32
# not using imagenet_weights
# Model: "VGG_base_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 32)   320         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# target_conv (Conv2D)            (None, 10, 10, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 5, 128)    0           target_conv[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, 128)]        0           global_average_pooling2d_2[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 93,962
# Trainable params: 93,962
# Non-trainable params: 0
# __________________________________________________________________________________________________
# weights loaded
# threshold:  0.5
# l1 weight:  2.0
# training CF model for alter class:  2
# Training CF model for PPs
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# counterfactual_model (Functiona (None, 128)          109184      input_5[0][0]
# __________________________________________________________________________________________________
# VGG_base_model (Functional)     [(None, 10), (None,  93962       input_5[0][0]
#                                                                  counterfactual_model[0][0]
# ==================================================================================================
# Total params: 110,474
# Trainable params: 16,512
# Non-trainable params: 93,962
# __________________________________________________________________________________________________
# training for fixed alter class:  2
# epoch 0: 100%|█| 1875/1875 [00:14<00:00, 131.24it/s, acc=0.998, loss=[0.030992284, 0.47266397, -0.2361846, 0.0, 8.02185
# epoch 1: 100%|████| 1875/1875 [00:11<00:00, 157.44it/s, acc=1, loss=[0.030315893, 0.29304245, -0.212732, 0.0, 4.91075]]
# epoch 2: 100%|█| 1875/1875 [00:11<00:00, 157.40it/s, acc=1, loss=[0.029021615, 0.30014658, -0.22697148, 0.0, 5.0972667]
# epoch 3: 100%|████| 1875/1875 [00:11<00:00, 156.62it/s, acc=1, loss=[0.025117733, 0.30143353, -0.2316142, 0.0, 5.0959]]
# epoch 4: 100%|██| 1875/1875 [00:12<00:00, 156.05it/s, acc=1, loss=[0.02337209, 0.30033162, -0.23320079, 0.0, 5.060633]]
# epoch 5: 100%|█| 1875/1875 [00:11<00:00, 157.12it/s, acc=1, loss=[0.022666195, 0.2996942, -0.23429106, 0.0, 5.0554166]]
# epoch 6: 100%|███| 1875/1875 [00:11<00:00, 158.68it/s, acc=1, loss=[0.021836689, 0.2996915, -0.23565313, 0.0, 5.07535]]
# epoch 7: 100%|█████| 1875/1875 [00:12<00:00, 150.19it/s, acc=1, loss=[0.02050719, 0.3001853, -0.23721442, 0.0, 5.1159]]
# epoch 8: 100%|█| 1875/1875 [00:12<00:00, 148.88it/s, acc=1, loss=[0.020033779, 0.29955384, -0.23755907, 0.0, 5.1124835]
# epoch 9: 100%|█| 1875/1875 [00:12<00:00, 152.10it/s, acc=1, loss=[0.019743793, 0.2988006, -0.23752062, 0.0, 5.0980167]]
# epoch 10: 100%|█| 1875/1875 [00:11<00:00, 156.65it/s, acc=1, loss=[0.01956241, 0.29814118, -0.23742391, 0.0, 5.0815835]
# epoch 11: 100%|█| 1875/1875 [00:12<00:00, 154.76it/s, acc=1, loss=[0.019420443, 0.29770806, -0.23738877, 0.0, 5.0684333
# epoch 12: 100%|█| 1875/1875 [00:12<00:00, 152.16it/s, acc=1, loss=[0.01933935, 0.29720432, -0.23723452, 0.0, 5.055267]]
# epoch 13: 100%|█| 1875/1875 [00:12<00:00, 152.94it/s, acc=1, loss=[0.019261945, 0.29682735, -0.23714244, 0.0, 5.0443835
# epoch 14: 100%|██| 1875/1875 [00:11<00:00, 156.92it/s, acc=1, loss=[0.019179553, 0.2965332, -0.23707229, 0.0, 5.03625]]
# epoch 15: 100%|██| 1875/1875 [00:12<00:00, 155.98it/s, acc=1, loss=[0.019102084, 0.29628712, -0.2370253, 0.0, 5.02845]]
# epoch 16: 100%|█| 1875/1875 [00:12<00:00, 155.19it/s, acc=1, loss=[0.019067539, 0.29599223, -0.23693746, 0.0, 5.0203667
# epoch 17: 100%|█████| 1875/1875 [00:11<00:00, 157.29it/s, acc=1, loss=[0.019029096, 0.29578546, -0.2369, 0.0, 5.01425]]
# epoch 18: 100%|█| 1875/1875 [00:12<00:00, 155.97it/s, acc=1, loss=[0.01899072, 0.29555646, -0.23684219, 0.0, 5.0072665]
# epoch 19: 100%|█| 1875/1875 [00:12<00:00, 153.21it/s, acc=1, loss=[0.018940639, 0.29536778, -0.23678763, 0.0, 5.001867]
# epoch 20: 100%|█| 1875/1875 [00:12<00:00, 145.53it/s, acc=1, loss=[0.018909344, 0.2952619, -0.23683092, 0.0, 4.9979334]
# epoch 21: 100%|██| 1875/1875 [00:12<00:00, 149.36it/s, acc=1, loss=[0.01893258, 0.2949752, -0.2367019, 0.0, 4.9918165]]
# epoch 22: 100%|██| 1875/1875 [00:12<00:00, 155.84it/s, acc=1, loss=[0.018874861, 0.29489875, -0.2367323, 0.0, 4.98875]]
# epoch 23: 100%|█| 1875/1875 [00:11<00:00, 156.75it/s, acc=1, loss=[0.018917672, 0.29468834, -0.23667571, 0.0, 4.9839334
# epoch 24: 100%|█| 1875/1875 [00:12<00:00, 155.75it/s, acc=1, loss=[0.018921135, 0.2945221, -0.23664516, 0.0, 4.9806333]
# epoch 25: 100%|█| 1875/1875 [00:11<00:00, 156.59it/s, acc=1, loss=[0.018934827, 0.29431865, -0.23657444, 0.0, 4.9776835
# epoch 26: 100%|█| 1875/1875 [00:11<00:00, 157.16it/s, acc=1, loss=[0.018954037, 0.29419896, -0.23657502, 0.0, 4.97535]]
# epoch 27: 100%|█| 1875/1875 [00:11<00:00, 157.43it/s, acc=1, loss=[0.019049685, 0.2939303, -0.23648448, 0.0, 4.9731665]
# epoch 28: 100%|█| 1875/1875 [00:11<00:00, 158.64it/s, acc=1, loss=[0.01910546, 0.29371634, -0.23642373, 0.0, 4.9716334]
# epoch 29: 100%|█| 1875/1875 [00:11<00:00, 158.00it/s, acc=1, loss=[0.019212024, 0.29349387, -0.23636265, 0.0, 4.971017]
# epoch 30: 100%|█| 1875/1875 [00:12<00:00, 156.01it/s, acc=1, loss=[0.019411596, 0.29322255, -0.23629671, 0.0, 4.971783]
# epoch 31: 100%|█| 1875/1875 [00:11<00:00, 156.97it/s, acc=1, loss=[0.019807106, 0.29281694, -0.23617621, 0.0, 4.9746666
# epoch 32: 100%|█| 1875/1875 [00:11<00:00, 158.69it/s, acc=1, loss=[0.02233124, 0.29137817, -0.23555939, 0.0, 4.9942665]
# epoch 33: 100%|█| 1875/1875 [00:11<00:00, 156.66it/s, acc=1, loss=[0.028574485, 0.2880453, -0.23238711, 0.0, 5.006933]]
# epoch 34: 100%|██| 1875/1875 [00:11<00:00, 157.86it/s, acc=1, loss=[0.028259898, 0.28688383, -0.23115768, 0.0, 4.9739]]
# epoch 35: 100%|█| 1875/1875 [00:11<00:00, 156.36it/s, acc=1, loss=[0.027878227, 0.28588825, -0.23039442, 0.0, 4.9502335
# epoch 36: 100%|██| 1875/1875 [00:11<00:00, 158.25it/s, acc=1, loss=[0.027743371, 0.28547707, -0.23003869, 0.0, 4.9381]]
# epoch 37: 100%|█| 1875/1875 [00:11<00:00, 157.74it/s, acc=1, loss=[0.027470654, 0.2848226, -0.22960573, 0.0, 4.9242167]
# epoch 38: 100%|█| 1875/1875 [00:11<00:00, 156.51it/s, acc=1, loss=[0.027316283, 0.28455248, -0.22937536, 0.0, 4.9174833
# epoch 39: 100%|█| 1875/1875 [00:12<00:00, 153.73it/s, acc=1, loss=[0.027055461, 0.2842731, -0.22917232, 0.0, 4.9103165]
# epoch 40: 100%|█| 1875/1875 [00:11<00:00, 156.27it/s, acc=1, loss=[0.026790528, 0.2838098, -0.22887044, 0.0, 4.901933]]
# epoch 41: 100%|██| 1875/1875 [00:11<00:00, 158.86it/s, acc=1, loss=[0.026383223, 0.2834733, -0.22869393, 0.0, 4.89675]]
# epoch 42: 100%|█| 1875/1875 [00:11<00:00, 156.60it/s, acc=1, loss=[0.02608603, 0.28316233, -0.22854263, 0.0, 4.8914332]
# epoch 43: 100%|█| 1875/1875 [00:11<00:00, 158.15it/s, acc=1, loss=[0.025877079, 0.2828414, -0.22834298, 0.0, 4.886083]]
# epoch 44: 100%|█| 1875/1875 [00:11<00:00, 160.77it/s, acc=1, loss=[0.025678074, 0.28246424, -0.22814016, 0.0, 4.8806667
# epoch 45: 100%|█| 1875/1875 [00:11<00:00, 158.96it/s, acc=1, loss=[0.025445534, 0.28219742, -0.22802255, 0.0, 4.876983]
# epoch 46: 100%|█| 1875/1875 [00:11<00:00, 159.68it/s, acc=1, loss=[0.02526266, 0.28202903, -0.22794451, 0.0, 4.8747334]
# epoch 47: 100%|███| 1875/1875 [00:11<00:00, 158.06it/s, acc=1, loss=[0.025005227, 0.2817545, -0.22783436, 0.0, 4.8712]]
# epoch 48: 100%|██| 1875/1875 [00:11<00:00, 159.23it/s, acc=1, loss=[0.024826456, 0.2814535, -0.22770695, 0.0, 4.86795]]
# epoch 49: 100%|█| 1875/1875 [00:11<00:00, 160.71it/s, acc=1, loss=[0.024716062, 0.28122032, -0.22758654, 0.0, 4.864567]
# epoch 50: 100%|█| 1875/1875 [00:11<00:00, 159.12it/s, acc=1, loss=[0.024504581, 0.28105024, -0.22757502, 0.0, 4.8628836
# epoch 51: 100%|█| 1875/1875 [00:11<00:00, 158.56it/s, acc=1, loss=[0.02439024, 0.28090653, -0.22751337, 0.0, 4.8617835]
# epoch 52: 100%|█| 1875/1875 [00:11<00:00, 157.16it/s, acc=1, loss=[0.024276836, 0.28072518, -0.22747047, 0.0, 4.8589835
# epoch 53: 100%|█| 1875/1875 [00:12<00:00, 155.74it/s, acc=1, loss=[0.024142781, 0.28070995, -0.22750117, 0.0, 4.859783]
# epoch 54: 100%|█| 1875/1875 [00:11<00:00, 157.91it/s, acc=1, loss=[0.024030829, 0.28047672, -0.22738905, 0.0, 4.85685]]
# epoch 55: 100%|█| 1875/1875 [00:11<00:00, 158.14it/s, acc=1, loss=[0.023912715, 0.28033385, -0.22736883, 0.0, 4.8556166
# epoch 56: 100%|█| 1875/1875 [00:11<00:00, 159.34it/s, acc=1, loss=[0.023849485, 0.28025404, -0.22733231, 0.0, 4.85415]]
# epoch 57: 100%|█████| 1875/1875 [00:11<00:00, 156.45it/s, acc=1, loss=[0.0237784, 0.2801087, -0.22728923, 0.0, 4.8521]]
# epoch 58: 100%|█| 1875/1875 [00:11<00:00, 159.99it/s, acc=1, loss=[0.023721768, 0.28007346, -0.22732307, 0.0, 4.852033]
# epoch 59: 100%|█| 1875/1875 [00:11<00:00, 158.65it/s, acc=1, loss=[0.023603516, 0.2800012, -0.22731575, 0.0, 4.850983]]
# epoch 60: 100%|█| 1875/1875 [00:11<00:00, 158.18it/s, acc=1, loss=[0.023584927, 0.27985454, -0.22725552, 0.0, 4.8487835
# epoch 61: 100%|██| 1875/1875 [00:11<00:00, 159.34it/s, acc=1, loss=[0.02353178, 0.27974516, -0.22723146, 0.0, 4.84725]]
# epoch 62: 100%|█| 1875/1875 [00:11<00:00, 158.66it/s, acc=1, loss=[0.023491414, 0.2797224, -0.22724895, 0.0, 4.8471665]
# epoch 63: 100%|███| 1875/1875 [00:11<00:00, 156.59it/s, acc=1, loss=[0.023490086, 0.2796924, -0.22726133, 0.0, 4.8459]]
# epoch 64: 100%|█| 1875/1875 [00:11<00:00, 159.42it/s, acc=1, loss=[0.023453152, 0.27960002, -0.22722045, 0.0, 4.8447833
# epoch 65: 100%|█| 1875/1875 [00:11<00:00, 158.30it/s, acc=1, loss=[0.023384577, 0.2795809, -0.22725804, 0.0, 4.844617]]
# epoch 66: 100%|█| 1875/1875 [00:11<00:00, 159.03it/s, acc=1, loss=[0.023413422, 0.27953675, -0.22725858, 0.0, 4.8433833
# epoch 67: 100%|██| 1875/1875 [00:11<00:00, 157.96it/s, acc=1, loss=[0.023336593, 0.27947563, -0.22724116, 0.0, 4.8431]]
# epoch 68: 100%|█| 1875/1875 [00:11<00:00, 159.95it/s, acc=1, loss=[0.023363197, 0.27938387, -0.2272163, 0.0, 4.8404164]
# epoch 69: 100%|█| 1875/1875 [00:11<00:00, 159.32it/s, acc=1, loss=[0.023347706, 0.27934325, -0.22721194, 0.0, 4.8405333
# epoch 70: 100%|██| 1875/1875 [00:11<00:00, 159.09it/s, acc=1, loss=[0.02328558, 0.27936745, -0.22725983, 0.0, 4.84095]]
# epoch 71: 100%|█| 1875/1875 [00:11<00:00, 158.84it/s, acc=1, loss=[0.023281861, 0.27927712, -0.2272355, 0.0, 4.8383164]
# epoch 72: 100%|██| 1875/1875 [00:11<00:00, 157.90it/s, acc=1, loss=[0.023278628, 0.27925736, -0.22724304, 0.0, 4.8387]]
# epoch 73: 100%|█| 1875/1875 [00:11<00:00, 156.49it/s, acc=1, loss=[0.023226386, 0.27928442, -0.22730573, 0.0, 4.8394666
# epoch 74: 100%|█| 1875/1875 [00:12<00:00, 153.09it/s, acc=1, loss=[0.02323814, 0.27918527, -0.22727025, 0.0, 4.8371334]
# epoch 75: 100%|████| 1875/1875 [00:12<00:00, 156.01it/s, acc=1, loss=[0.023182102, 0.2792241, -0.227312, 0.0, 4.83795]]
# epoch 76: 100%|██| 1875/1875 [00:12<00:00, 154.20it/s, acc=1, loss=[0.023275124, 0.2790899, -0.22724834, 0.0, 4.83525]]
# epoch 77: 100%|█| 1875/1875 [00:12<00:00, 152.90it/s, acc=1, loss=[0.023165915, 0.279205, -0.22735661, 0.0, 4.8374166]]
# epoch 78: 100%|█| 1875/1875 [00:12<00:00, 154.15it/s, acc=1, loss=[0.023159688, 0.27915543, -0.22735067, 0.0, 4.83665]]
# epoch 79: 100%|█| 1875/1875 [00:12<00:00, 154.40it/s, acc=1, loss=[0.023163786, 0.2790373, -0.22731225, 0.0, 4.8341165]
# epoch 80: 100%|█| 1875/1875 [00:12<00:00, 152.27it/s, acc=1, loss=[0.023165269, 0.27904633, -0.227327, 0.0, 4.8348165]]
# epoch 81: 100%|█| 1875/1875 [00:12<00:00, 155.86it/s, acc=1, loss=[0.023109699, 0.27897996, -0.22732425, 0.0, 4.83445]]
# epoch 82: 100%|█| 1875/1875 [00:12<00:00, 154.48it/s, acc=1, loss=[0.023162642, 0.27894044, -0.22731984, 0.0, 4.83405]]
# epoch 83: 100%|█| 1875/1875 [00:11<00:00, 157.33it/s, acc=1, loss=[0.02319404, 0.27884156, -0.2273238, 0.0, 4.8364167]]
# epoch 84: 100%|███| 1875/1875 [00:12<00:00, 155.29it/s, acc=1, loss=[0.0232712, 0.27838904, -0.22715242, 0.0, 4.84125]]
# epoch 85: 100%|██| 1875/1875 [00:12<00:00, 154.16it/s, acc=1, loss=[0.023468861, 0.27792165, -0.2270478, 0.0, 4.84025]]
# epoch 86: 100%|█| 1875/1875 [00:12<00:00, 151.24it/s, acc=1, loss=[0.023574352, 0.2776002, -0.22697002, 0.0, 4.8349333]
# epoch 87: 100%|█| 1875/1875 [00:12<00:00, 154.81it/s, acc=1, loss=[0.023688605, 0.27732217, -0.22687383, 0.0, 4.8276167
# epoch 88: 100%|█| 1875/1875 [00:12<00:00, 155.15it/s, acc=1, loss=[0.02376748, 0.2772157, -0.22684602, 0.0, 4.8234167]]
# epoch 89: 100%|███| 1875/1875 [00:11<00:00, 158.38it/s, acc=1, loss=[0.023816593, 0.2770787, -0.22680384, 0.0, 4.8167]]
# epoch 90: 100%|██| 1875/1875 [00:11<00:00, 158.76it/s, acc=1, loss=[0.023938233, 0.2769614, -0.2267351, 0.0, 4.812033]]
# epoch 91: 100%|█| 1875/1875 [00:11<00:00, 157.10it/s, acc=1, loss=[0.023976048, 0.27685475, -0.22668517, 0.0, 4.80695]]
# epoch 92: 100%|█| 1875/1875 [00:12<00:00, 150.61it/s, acc=1, loss=[0.024015492, 0.27680594, -0.22667116, 0.0, 4.8044834
# epoch 93: 100%|█| 1875/1875 [00:12<00:00, 150.30it/s, acc=1, loss=[0.02404709, 0.2768245, -0.22670035, 0.0, 4.8024335]]
# epoch 94: 100%|█| 1875/1875 [00:12<00:00, 153.52it/s, acc=1, loss=[0.024122564, 0.27672365, -0.22663777, 0.0, 4.798567]
# epoch 95: 100%|███| 1875/1875 [00:11<00:00, 159.58it/s, acc=1, loss=[0.0241486, 0.2766155, -0.22657537, 0.0, 4.795067]]
# epoch 96: 100%|█| 1875/1875 [00:11<00:00, 159.60it/s, acc=1, loss=[0.024184978, 0.2766393, -0.22660635, 0.0, 4.7942667]
# epoch 97: 100%|██| 1875/1875 [00:11<00:00, 160.26it/s, acc=1, loss=[0.024222769, 0.2766351, -0.22660676, 0.0, 4.79235]]
# epoch 98: 100%|█| 1875/1875 [00:11<00:00, 160.17it/s, acc=1, loss=[0.024269497, 0.27651292, -0.22652543, 0.0, 4.7896667
# epoch 99: 100%|█| 1875/1875 [00:11<00:00, 157.17it/s, acc=1, loss=[0.02426048, 0.27655995, -0.22657906, 0.0, 4.7886834]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# E:\Medical Imaging Diagnostic (MID) Lab\XAI in MID\my_implementation_interpretable_CNN\my_interpretable_CNN.py in <module>
#    1115         ipython = get_ipython()
#    1116         ipython.magic("reset -f")
# -> 1117         sys.exit()
#    1118     else:
#    1119         #counterfactual_generator.load_weights(filepath=weights_path+'/counterfactual_generator_model.hdf5')
#
# NameError: name 'sys' is not defined
